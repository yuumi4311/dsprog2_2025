# %% [markdown]
# # Python演習課題3

# %% [markdown]
# ### 問1
#
# 自然数を入力とし、入力された自然数が3の倍数(Ex. 3, 6, 9, ...)であるときは`hoge`、3を含む数(Ex. 3, 13, 23, ...)であるときは`huga`、両方の条件を満たす時は`piyo`を出力する関数`nabeatsu`を定義してください
#
# また、以下のテストケースを入力した際の出力結果を示してください
#
# ```
# # テストケース1
# 6
#
# # テストケース2
# 13
#
# # テストケース3
# 33
# ```

# %%
def nabeatsu(num: int) -> str:
    is_multiple_of_3 = (num % 3 == 0)
    contains_3 = ("3" in str(num))

    if is_multiple_of_3 and contains_3:
        return "piyo"
    elif is_multiple_of_3:
        return "hoge"
    elif contains_3:
        return "huga"
    else:
        return ""

# %%
case_1 = 6
case_2 = 13
case_3 = 33

print('case_1:', nabeatsu(case_1))
print('case_2:', nabeatsu(case_2))
print('case_3:', nabeatsu(case_3))
# Out:
# case_1: hoge
# case_2: huga
# case_3: piyo

# %% [markdown]
# ### 問2
#
# 異なる自然数を含む配列とターゲットとなる自然数を入力として、配列に含まれる自然数を足し合わせてターゲットとなる自然数になる組み合わせを出力する関数`combination_sum`を定義してください
#
# このとき、同じ自然数は何度でも利用してよいものとし、もし組み合わせが存在しない場合は空の配列を返してください
#
# 例えば、配列`[2, 3, 6, 7]`、ターゲット`7`を入力としたときの出力は`[[2,2,3],[7]]`になります
#
# また、以下のテストケースを入力した際の出力結果を示してください
#
# ```
# # テストケース1
# 配列: [2, 3, 6, 7]
# ターゲット: 14
#
# # テストケース2
# 配列: [2, 3, 5]
# ターゲット: 8
#
# # テストケース3
# 配列: [2, 9, 11]
# ターゲット: 100
# ```

# %%
def combination_sum(candidates: list, target: int) -> list:
    result = []
    candidates.sort()  # 昇順にして探索を安定させる

    def backtrack(start: int, current: list, total: int):
        if total == target:
            result.append(current.copy())
            return
        if total > target:
            return

        for i in range(start, len(candidates)):
            num = candidates[i]
            current.append(num)
            # 同じ数を何度でも使えるので i をそのまま渡す
            backtrack(i, current, total + num)
            current.pop()

    backtrack(0, [], 0)
    return result

# %%
candidates_1 = [2, 3, 6, 7]
target_1 = 14

candidates_2 = [2, 3, 5]
target_2 = 8

candidates_3 = [2, 9, 11]
target_3 = 100

print(combination_sum(candidates_1, target_1))
print(combination_sum(candidates_2, target_2))
print(combination_sum(candidates_3, target_3))
# Out:
# [[2, 2, 2, 2, 2, 2, 2], [2, 2, 2, 2, 3, 3], [2, 2, 2, 2, 6], [2, 2, 3, 7], [2, 3, 3, 3, 3], [2, 3, 3, 6], [2, 6, 6], [7, 7]]
# [[2, 2, 2, 2], [2, 3, 3], [3, 5]]
# [[2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 9], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 11, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 11, 11, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 9, 9, 9], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 9, 9, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 9, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 11, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 11, 11, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 11, 11, 11, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 11, 11, 11, 11, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 9, 9, 9, 9, 9], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 9, 9, 9, 9, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 9, 9, 9, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 9, 9, 11, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 9, 11, 11, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 9, 11, 11, 11, 11, 11], [2, 2, 2, 2, 2, 2, 2, 2, 9, 9, 11, 11, 11, 11, 11, 11], [2, 2, 2, 2, 2, 2, 2, 9, 11, 11, 11, 11, 11, 11, 11], [2, 2, 2, 2, 2, 2, 11, 11, 11, 11, 11, 11, 11, 11], [2, 2, 2, 2, 2, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9], [2, 2, 2, 2, 9, 9, 9, 9, 9, 9, 9, 9, 9, 11], [2, 2, 2, 9, 9, 9, 9, 9, 9, 9, 9, 11, 11], [2, 2, 9, 9, 9, 9, 9, 9, 9, 11, 11, 11], [2, 9, 9, 9, 9, 9, 9, 11, 11, 11, 11], [9, 9, 9, 9, 9, 11, 11, 11, 11, 11]]

# %% [markdown]
# ### 問3
#
# 括弧を含む文字列を入力として、括弧の内包関係が正しいかどうかを判定し、正しければ`True`、正しくなければ`False`を返す関数`format_checker`を定義してください
#
# 例えば、`[](){}`や`[({})]`は正しい、`[(]`や`{[(})]`は正しくないと判定します
#
# また、以下のテストケースを入力した際の出力結果を示してください
#
# ```
# # テストケース1
# Hello I’m [(firstname) (lastname)] and I’m {age} years old!
#
# # テストケース2
# Hello I’m [(firstname) (lastname]) and I’m {age} years old!
#
# # テストケース3
# Hello I’m ((firstname) (lastname) and I’m {age} years old!
# ```

# %%
def format_checker(text: str) -> bool:
    stack = []
    pairs = {
        ')': '(',
        ']': '[',
        '}': '{'
    }

    for ch in text:
        # 開き括弧
        if ch in pairs.values():
            stack.append(ch)

        # 閉じ括弧
        elif ch in pairs:
            if not stack:
                return False
            if stack.pop() != pairs[ch]:
                return False

    # 最後にスタックが空なら正しい
    return len(stack) == 0

# %%
case_1 = 'Hello I’m [(firstname) (lastname)] and I’m {age} years old!'
case_2 = 'Hello I’m [(firstname) (lastname]) and I’m {age} years old!'
case_3 = 'Hello I’m ((firstname) (lastname) and I’m {age} years old!'

print('case_1:', format_checker(case_1))
print('case_2:', format_checker(case_2))
print('case_3:', format_checker(case_3))
# Out:
# case_1: True
# case_2: False
# case_3: False
