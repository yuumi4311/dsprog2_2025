# %% [markdown]
# # Python演習課題2

# %% [markdown]
# ## 課題1
#
# 各問で示されている図を出力してください。
#
# その際、以下の要件を必ず満たすようにしてください。
#
#
# 1.   for文を必ず用いること
# 2.   変数`size`の値を変えることで自由に図形の大きさを変更できること

# %% [markdown]
# ### 問1
#
# 以下の図形を出力してください。
#
# ```
# *
# **
# ***
# ****
# *****
# ```

# %%
size = 5

# %% [markdown]
# ### 問2
#
# 以下の図形を出力してください。
#
# ```
# *
#  *
#   *
#    *
#     *
# ```

# %%
size = 5

# %% [markdown]
# ### 問3
#
# 以下の図形を出力してください。
#
# ```
#     *
#    *
#   *
#  *
# *
# ```

# %%
size = 5

# %% [markdown]
# ### 問4
#
# 以下の図形を出力してください。
#
# ```
# *   *
#  * *
#   *
#  * *
# *   *
# ```

# %%
size = 5

# %% [markdown]
# ### 問5
#
# 以下の図形を出力してください。
#
# ```
#     *
#    ***
#   *****
#  *******
# *********
# ```

# %%
size = 5
