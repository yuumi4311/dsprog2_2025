# %% [markdown]
# # 第1回授業課題

# %% [markdown]
# ## スクレイピング

# %%
import requests
from bs4 import BeautifulSoup
import time

def scrape_google_repos_all():
    # Googleが管理しているリポジトリ
    base_url = "https://github.com/orgs/google/repositories?q=&type=all&language=&sort=stargazers"
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36",
    }

    all_data = []
    page = 1
    
    max_pages = 100

    print(f"スクレイピング開始")
    print("-" * 60)
    print(f"{'No.':<4} | {'リポジトリ名':<30} | {'言語':<10} | {'スター数'}")
    print("-" * 60)
    
    total_count = 0

    # ページをめくるループ
    while page <= max_pages:
        
        # URLに &page=ページ番号 をつける
        target_url = f"{base_url}&page={page}"
        
        try:
            response = requests.get(target_url, headers=headers, timeout=10)
            response.raise_for_status()
        except Exception as e:
            print(f"ページ取得エラー: {e}")
            break

        soup = BeautifulSoup(response.text, 'html.parser')
        
        # リポジトリ名（h3）を取得
        all_h3 = soup.find_all('h3')
        
        # もしこのページにリポジトリがなければ終了（最後のページ）
        if not all_h3:
            print("これ以上リポジトリがありません。終了します。")
            break
            
        items_on_page = 0

        for h3 in all_h3:
            a_tag = h3.find('a')
            if not a_tag: continue
            href = a_tag.get('href', '')
            if not href.strip().startswith('/google/'): continue
                
            name = a_tag.text.strip()
            
            # 親要素を探す
            parent = h3.find_parent('li')
            if not parent: parent = h3.find_parent('div', class_='Box-row')
            if not parent: parent = h3.parent.parent
            
            language = "Unknown"
            stars = "0"
            
            if parent:
                # 言語取得
                color_dot = parent.find('span', style=lambda s: s and 'background-color' in s)
                if color_dot:
                    language = color_dot.parent.text.strip()
                else:
                    target_spans = parent.find_all('span', class_=lambda c: c and 'ReposListItem-module__Text' in c)
                    for span in target_spans:
                        text = span.text.strip()
                        if "Updated" not in text and "License" not in text and not text.isdigit() and len(text) < 20:
                            language = text
                            break

                # スター数取得
                star_tag = parent.find('a', href=lambda x: x and 'stargazers' in x)
                if star_tag:
                    stars = star_tag.text.strip().replace(',', '')
                else:
                    star_span = parent.find('span', id=lambda x: x and 'star' in x)
                    if star_span:
                        stars = star_span.text.strip().replace(',', '')

            language = language.replace('\n', '').strip()
            
            # 表示とリスト追加
            total_count += 1
            print(f"{total_count:<4} | {name:<30} | {language:<10} | {stars}")
            all_data.append((name, language, stars))
            
            items_on_page += 1
            
            # ★ここ大事！1件ごとに1秒待つ（課題ルール）
            time.sleep(1)
        
        # もしこのページで何も取れなかったら終了
        if items_on_page == 0:
            print("データが見つかりませんでした。終了します。")
            break
            
        # 次のページへ
        page += 1
        # ページ遷移の間にも少し休憩（サーバー負荷軽減）
        time.sleep(2)

    print("-" * 60)
    print(f"完了: 合計 {len(all_data)} 件取得しました。")
    return all_data

# 実行
scraped_data = scrape_google_repos_all()
# Out:
# スクレイピング開始
# ------------------------------------------------------------
# No.  | リポジトリ名                         | 言語         | スター数
# ------------------------------------------------------------
# 1    | material-design-icons          | Unknown    | 53k
# 2    | guava                          | Java       | 51k
# 3    | zx                             | JavaScript | 45k
# 4    | styleguide                     | HTML       | 39k
# 5    | leveldb                        | C++        | 38k
# 6    | googletest                     | C++        | 38k
# 7    | comprehensive-rust             | Rust       | 32k
# 8    | material-design-lite           | HTML       | 32k
# 9    | python-fire                    | Python     | 28k
# 10   | flatbuffers                    | C++        | 25k
# 11   | gson                           | Java       | 24k
# 12   | ExoPlayer                      | Java       | 22k
# 13   | iosched                        | Kotlin     | 22k
# 14   | eng-practices                  | Unknown    | 20k
# 15   | fonts                          | HTML       | 19k
# 16   | filament                       | C++        | 19k
# 17   | cadvisor                       | Go         | 19k
# 18   | web-starter-kit                | HTML       | 18k
# 19   | flexbox-layout                 | Kotlin     | 18k
# 20   | libphonenumber                 | C++        | 18k
# 21   | dagger                         | Java       | 18k
# 22   | gvisor                         | Go         | 17k
# 23   | langextract                    | Python     | 17k
# 24   | adk-python                     | Python     | 16k
# 25   | brotli                         | TypeScript | 14k
# 26   | wire                           | Go         | 14k
# 27   | yapf                           | Python     | 14k
# 28   | WebFundamentals                | JavaScript | 14k
# 29   | deepdream                      | Unknown    | 13k
# 30   | guetzli                        | C++        | 13k
# 31   | or-tools                       | C++        | 13k
# 32   | guice                          | Java       | 13k
# 33   | sanitizers                     | C          | 12k
# 34   | oss-fuzz                       | Shell      | 12k
# 35   | sentencepiece                  | C++        | 11k
# 36   | go-github                      | Go         | 11k
# 37   | dopamine                       | Jupyter Notebook | 11k
# 38   | auto                           | Java       | 11k
# 39   | grumpy                         | Go         | 11k
# 40   | skia                           | C++        | 10k
# 41   | benchmark                      | C++        | 9.9k
# 42   | magika                         | Python     | 9.8k
# 43   | go-cloud                       | Go         | 9.8k
# 44   | re2                            | C++        | 9.5k
# 45   | pprof                          | Go         | 8.9k
# 46   | tsunami-security-scanner       | Java       | 8.5k
# 47   | trax                           | Python     | 8.3k
# 48   | traceur-compiler               | JavaScript | 8.2k
# 49   | osv-scanner                    | Go         | 8.1k
# 50   | diff-match-patch               | Python     | 8k
# 51   | accompanist                    | Kotlin     | 7.8k
# 52   | model-viewer                   | TypeScript | 7.7k
# 53   | closure-compiler               | JavaScript | 7.6k
# 54   | android-classyshark            | Java       | 7.6k
# 55   | latexify_py                    | Python     | 7.6k
# 56   | jsonnet                        | Jsonnet    | 7.4k
# 57   | glog                           | C++        | 7.3k
# 58   | agera                          | Java       | 7.2k
# 59   | error-prone                    | Java       | 7.1k
# 60   | flutter-desktop-embedding      | C++        | 7.1k
# 61   | draco                          | C++        | 7k
# 62   | gops                           | Go         | 7k
# 63   | flax                           | Jupyter Notebook | 6.9k
# 64   | lovefield                      | JavaScript | 6.8k
# 65   | gopacket                       | Go         | 6.7k
# 66   | gemma.cpp                      | C++        | 6.6k
# 67   | snappy                         | C++        | 6.5k
# 68   | adk-samples                    | Python     | 6.5k
# 69   | automl                         | Jupyter Notebook | 6.4k
# 70   | wireit                         | TypeScript | 6.3k
# 71   | grafika                        | Java       | 6.1k
# 72   | ios-webkit-debug-proxy         | C          | 6.1k
# 73   | j2objc                         | Java       | 6k
# 74   | physical-web                   | Java       | 6k
# 75   | google-java-format             | Java       | 6k
# 76   | syzkaller                      | Go         | 5.9k
# 77   | uuid                           | Go         | 5.9k
# 78   | bbr                            | Unknown    | 5.8k
# 79   | seesaw                         | Go         | 5.7k
# 80   | EarlGrey                       | Objective-C | 5.7k
# 81   | seq2seq                        | Python     | 5.6k
# 82   | gemma_pytorch                  | Python     | 5.6k
# 83   | clusterfuzz                    | Python     | 5.5k
# 84   | battery-historian              | Go         | 5.4k
# 85   | clasp                          | TypeScript | 5.3k
# 86   | google-authenticator           | Java       | 5.3k
# 87   | bloaty                         | C++        | 5.3k
# 88   | git-appraise                   | Go         | 5.3k
# 89   | gts                            | TypeScript | 5.2k
# 90   | gumbo-parser                   | HTML       | 5.2k
# 91   | highway                        | C++        | 5.1k
# 92   | tf-quant-finance               | Python     | 5.1k
# 93   | pytype                         | Python     | 5k
# 94   | perfetto                       | C++        | 5k
# 95   | tcmalloc                       | C++        | 5k
# 96   | grr                            | Python     | 5k
# 97   | pebble                         | C          | 4.9k
# 98   | closure-library                | JavaScript | 4.9k
# 99   | liquidfun                      | C++        | 4.9k
# 100  | google-ctf                     | Python     | 4.8k
# 101  | adk-go                         | Go         | 4.8k
# 102  | cameraview                     | Java       | 4.7k
# 103  | wuffs                          | C          | 4.7k
# 104  | go-cmp                         | Go         | 4.5k
# 105  | santa                          | Objective-C++ | 4.5k
# 106  | gxui                           | Go         | 4.4k
# 107  | orbit                          | C++        | 4.3k
# 108  | open-location-code             | Java       | 4.3k
# 109  | security-research              | C          | 4.3k
# 110  | tamperchrome                   | TypeScript | 4.2k
# 111  | btree                          | Go         | 4.1k
# 112  | end-to-end                     | JavaScript | 4.1k
# 113  | eleventy-high-performance-blog | JavaScript | 4.1k
# 114  | AFL                            | C          | 4k
# 115  | mtail                          | Go         | 4k
# 116  | oboe                           | C++        | 4k
# 117  | lyra                           | C++        | 3.9k
# 118  | bundletool                     | Java       | 3.9k
# 119  | codesearch                     | Go         | 3.9k
# 120  | angle                          | C++        | 3.8k
# 121  | promises                       | Objective-C | 3.8k
# 122  | fuzzing                        | C++        | 3.7k
# 123  | rejoiner                       | Java       | 3.7k
# 124  | trillian                       | Go         | 3.7k
# 125  | fully-homomorphic-encryption   | C++        | 3.6k
# 126  | go-containerregistry           | Go         | 3.6k
# 127  | tarpc                          | Rust       | 3.6k
# 128  | nsjail                         | C++        | 3.6k
# 129  | deepvariant                    | Python     | 3.6k
# 130  | zopfli                         | C++        | 3.6k
# 131  | incremental-dom                | TypeScript | 3.5k
# 132  | recaptcha                      | PHP        | 3.5k
# 133  | cel-spec                       | Starlark   | 3.5k
# 134  | google-api-javascript-client   | CSS        | 3.4k
# 135  | robotstxt                      | C++        | 3.4k
# 136  | volley                         | Java       | 3.4k
# 137  | prompt-to-prompt               | Jupyter Notebook | 3.4k
# 138  | lmctfy                         | C++        | 3.4k
# 139  | cdc-file-transfer              | C++        | 3.4k
# 140  | skywater-pdk                   | Python     | 3.3k
# 141  | ksp                            | Kotlin     | 3.3k
# 142  | bottery                        | JavaScript | 3.3k
# 143  | honggfuzz                      | C          | 3.3k
# 144  | model_search                   | Python     | 3.3k
# 145  | differential-privacy           | Go         | 3.3k
# 146  | OpenSK                         | Rust       | 3.2k
# 147  | timesketch                     | Python     | 3.2k
# 148  | lisp-koans                     | Common Lisp | 3.2k
# 149  | BIG-bench                      | Python     | 3.2k
# 150  | earthengine-api                | JavaScript | 3.1k
# 151  | netstack                       | Go         | 3.1k
# 152  | eddystone                      | C          | 3.1k
# 153  | gif-for-cli                    | Python     | 2.9k
# 154  | nogotofail                     | Python     | 2.9k
# 155  | brax                           | Jupyter Notebook | 2.9k
# 156  | binnavi                        | Java       | 2.9k
# 157  | docsy                          | JavaScript | 2.9k
# 158  | mangle                         | Go         | 2.9k
# 159  | breakpad                       | C++        | 2.8k
# 160  | bindiff                        | Java       | 2.8k
# 161  | charts                         | Dart       | 2.8k
# 162  | cel-go                         | Go         | 2.8k
# 163  | truth                          | Java       | 2.8k
# 164  | mozc                           | C++        | 2.8k
# 165  | enjarify                       | Python     | 2.7k
# 166  | earthenterprise                | C++        | 2.7k
# 167  | mozc-devices                   | C++        | 2.7k
# 168  | forma                          | Rust       | 2.6k
# 169  | tracing-framework              | JavaScript | 2.6k
# 170  | hover                          | Java       | 2.6k
# 171  | omaha                          | C++        | 2.6k
# 172  | starlark-go                    | Go         | 2.6k
# 173  | cpu_features                   | C++        | 2.6k
# 174  | exposure-notifications-server  | Go         | 2.6k
# 175  | s2geometry                     | C++        | 2.6k
# 176  | jimfs                          | Java       | 2.5k
# 177  | copybara                       | Java       | 2.5k
# 178  | autocxx                        | Rust       | 2.5k
# 179  | zetasql                        | C++        | 2.4k
# 180  | swiftshader                    | C++        | 2.4k
# 181  | osv.dev                        | Python     | 2.4k
# 182  | youtube-8m                     | Python     | 2.4k
# 183  | neural-tangents                | Jupyter Notebook | 2.4k
# 184  | tangent                        | Python     | 2.3k
# 185  | souper                         | C++        | 2.3k
# 186  | gnostic                        | Go         | 2.2k
# 187  | gapid                          | Go         | 2.2k
# 188  | ngx_brotli                     | C          | 2.2k
# 189  | generative-ai-docs             | Jupyter Notebook | 2.2k
# 190  | XNNPACK                        | C          | 2.2k
# 191  | marzipano                      | JavaScript | 2.2k
# 192  | mathsteps                      | JavaScript | 2.1k
# 193  | gin-config                     | Python     | 2.1k
# 194  | go-querystring                 | Go         | 2.1k
# 195  | zerocopy                       | Rust       | 2.1k
# 196  | santa-tracker-android          | Java       | 2.1k
# 197  | shaderc                        | C++        | 2.1k
# 198  | boringssl                      | C++        | 2.1k
# 199  | martian                        | Go         | 2k
# 200  | android-emulator-container-scripts | Python     | 2k
# 201  | butteraugli                    | C++        | 2k
# 202  | spatial-media                  | Python     | 2k
# 203  | rekall                         | Python     | 2k
# 204  | marl                           | C++        | 2k
# 205  | google-authenticator-libpam    | C          | 1.9k
# 206  | rune                           | C          | 1.9k
# 207  | sling                          | C++        | 1.9k
# 208  | tunix                          | Python     | 1.9k
# 209  | nerfies                        | Python     | 1.9k
# 210  | security-research-pocs         | C++        | 1.9k
# 211  | fruit                          | C++        | 1.9k
# 212  | argh                           | Rust       | 1.9k
# 213  | android-emulator-m1-preview    | Unknown    | 1.9k
# 214  | TensorNetwork                  | Python     | 1.9k
# 215  | python-adb                     | Python     | 1.8k
# 216  | closure-compiler-js            | JavaScript | 1.8k
# 217  | compare_gan                    | Python     | 1.8k
# 218  | protobuf-gradle-plugin         | Groovy     | 1.8k
# 219  | gemmlowp                       | C++        | 1.8k
# 220  | stenographer                   | Go         | 1.8k
# 221  | CausalImpact                   | R          | 1.8k
# 222  | go-jsonnet                     | Go         | 1.8k
# 223  | eslint-config-google           | JavaScript | 1.8k
# 224  | nomulus                        | Java       | 1.8k
# 225  | periph                         | Go         | 1.7k
# 226  | zoekt                          | Unknown    | 1.7k
# 227  | sandboxed-api                  | C++        | 1.7k
# 228  | woff2                          | C++        | 1.7k
# 229  | novm                           | Go         | 1.7k
# 230  | aiyprojects-raspbian           | Python     | 1.7k
# 231  | google-authenticator-android   | Java       | 1.7k
# 232  | UIforETW                       | C++        | 1.6k
# 233  | yamlfmt                        | Go         | 1.6k
# 234  | pyringe                        | Python     | 1.6k
# 235  | vizier                         | Python     | 1.6k
# 236  | json_serializable.dart         | Dart       | 1.6k
# 237  | highwayhash                    | C++        | 1.6k
# 238  | uis-rnn                        | Python     | 1.6k
# 239  | keytransparency                | Go         | 1.6k
# 240  | log4jscanner                   | Go         | 1.6k
# 241  | uncertainty-baselines          | Python     | 1.6k
# 242  | budoux                         | Python     | 1.5k
# 243  | atheris                        | Python     | 1.5k
# 244  | gofuzz                         | Go         | 1.5k
# 245  | go-safeweb                     | Go         | 1.5k
# 246  | live-transcribe-speech-engine  | Java       | 1.5k
# 247  | flogger                        | Java       | 1.5k
# 248  | tensorstore                    | C++        | 1.5k
# 249  | fuzzer-test-suite              | C          | 1.5k
# 250  | flutter.widgets                | Dart       | 1.4k
# 251  | jsonapi                        | Go         | 1.4k
# 252  | ion                            | C++        | 1.4k
# 253  | haskell-trainings              | Haskell    | 1.4k
# 254  | firing-range                   | Java       | 1.4k
# 255  | cloudprober                    | Go         | 1.4k
# 256  | crfs                           | Go         | 1.4k
# 257  | mathfu                         | C++        | 1.4k
# 258  | xls                            | C++        | 1.4k
# 259  | conscrypt                      | Java       | 1.4k
# 260  | pinject                        | Python     | 1.3k
# 261  | j2cl                           | Java       | 1.3k
# 262  | site-kit-wp                    | JavaScript | 1.3k
# 263  | sg2im                          | Python     | 1.3k
# 264  | monster-mash                   | C++        | 1.3k
# 265  | oss-fuzz-gen                   | Python     | 1.3k
# 266  | style-aligned                  | Python     | 1.3k
# 267  | typograms                      | JavaScript | 1.3k
# 268  | visualblocks                   | TypeScript | 1.3k
# 269  | skicka                         | Go         | 1.3k
# 270  | brain-tokyo-workshop           | Jupyter Notebook | 1.3k
# 271  | schism                         | Scheme     | 1.3k
# 272  | coding-competitions-archive    | HTML       | 1.3k
# 273  | nftables                       | Go         | 1.3k
# 274  | codeworld                      | Haskell    | 1.3k
# 275  | secrets-gradle-plugin          | Kotlin     | 1.3k
# 276  | glazier                        | Python     | 1.2k
# 277  | re2j                           | Java       | 1.2k
# 278  | nsync                          | C          | 1.2k
# 279  | modernstorage                  | Kotlin     | 1.2k
# 280  | neuroglancer                   | TypeScript | 1.2k
# 281  | prettytensor                   | Python     | 1.2k
# 282  | swissgl                        | JavaScript | 1.2k
# 283  | cityhash                       | Shell      | 1.2k
# 284  | textfsm                        | Python     | 1.2k
# 285  | lullaby                        | C++        | 1.2k
# 286  | google-toolbox-for-mac         | Objective-C | 1.2k
# 287  | meridian                       | Python     | 1.2k
# 288  | skylark                        | Go         | 1.2k
# 289  | makani                         | C++        | 1.2k
# 290  | budou                          | Python     | 1.2k
# 291  | proto-quic                     | Unknown    | 1.2k
# 292  | double-conversion              | C++        | 1.2k
# 293  | active-learning                | Python     | 1.2k
# 294  | fuzzbench                      | Python     | 1.2k
# 295  | binexport                      | C++        | 1.2k
# 296  | intermock                      | TypeScript | 1.2k
# 297  | wwwbasic                       | JavaScript | 1.1k
# 298  | vim-codefmt                    | Vim Script | 1.1k
# 299  | ssl_logger                     | Python     | 1.1k
# 300  | schema-dts                     | TypeScript | 1.1k
# 301  | adb-sync                       | Python     | 1.1k
# 302  | keyczar                        | Unknown    | 1.1k
# 303  | cmockery                       | Shell      | 1.1k
# 304  | crosvm                         | Rust       | 1.1k
# 305  | jsaction                       | JavaScript | 1.1k
# 306  | mundane                        | Rust       | 1.1k
# 307  | capslock                       | Go         | 1.1k
# 308  | certificate-transparency-go    | Go         | 1.1k
# 309  | quiver-dart                    | Dart       | 1.1k
# 310  | agi                            | Go         | 1k
# 311  | lightweight_mmm                | Python     | 1k
# 312  | cluster-data                   | TeX        | 1k
# 313  | jaxopt                         | Python     | 1k
# 314  | ml_collections                 | Python     | 998
# 315  | dreambooth                     | Unknown    | 998
# 316  | kati                           | Rust       | 994
# 317  | it-cert-automation-practice    | Python     | 986
# 318  | badwolf                        | Go         | 984
# 319  | rowhammer-test                 | C++        | 984
# 320  | longfellow-zk                  | C++        | 983
# 321  | fscrypt                        | Go         | 983
# 322  | clif                           | C++        | 981
# 323  | asylo                          | C++        | 980
# 324  | adk-docs                       | HTML       | 976
# 325  | adk-java                       | Java       | 971
# 326  | go-licenses                    | Go         | 961
# 327  | packetdrill                    | C          | 950
# 328  | android-arscblamer             | Java       | 946
# 329  | hypernerf                      | Python     | 943
# 330  | tsunami-security-scanner-plugins | Java       | 942
# 331  | swift-benchmark                | Swift      | 936
# 332  | mipnerf                        | Python     | 933
# 333  | fuzztest                       | C++        | 925
# 334  | evojax                         | Jupyter Notebook | 925
# 335  | crubit                         | C++        | 924
# 336  | namebench                      | Go         | 923
# 337  | gousb                          | Go         | 919
# 338  | xsecurelock                    | C          | 914
# 339  | mr4c                           | Java       | 907
# 340  | fhir                           | C++        | 905
# 341  | jax-cfd                        | Jupyter Notebook | 894
# 342  | logger                         | Go         | 889
# 343  | nearby                         | C++        | 888
# 344  | built_value.dart               | Dart       | 883
# 345  | certificate-transparency       | C++        | 882
# 346  | inception                      | Unknown    | 878
# 347  | langfun                        | Python     | 875
# 348  | rappor                         | R          | 869
# 349  | inject.dart                    | Dart       | 867
# 350  | cld3                           | C++        | 856
# 351  | vsaq                           | JavaScript | 856
# 352  | ringdroid                      | Java       | 854
# 353  | transit                        | Unknown    | 852
# 354  | hdrnet                         | Python     | 851
# 355  | addlicense                     | Go         | 850
# 356  | android-emulator-hypervisor-driver | C          | 842
# 357  | capirca                        | Python     | 839
# 358  | visqol                         | C++        | 836
# 359  | swift                          | Unknown    | 836
# 360  | private-join-and-compute       | C++        | 834
# 361  | private-join-and-compute       | C++        | 834
# 362  | google-api-objectivec-client-for-rest | Objective-C | 830
# 363  | generative-ai-go               | Go         | 830
# 364  | macops                         | Python     | 827
# 365  | pygtrie                        | Python     | 824
# 366  | gcm                            | Java       | 823
# 367  | emoji-scavenger-hunt           | TypeScript | 819
# 368  | caliper                        | Java       | 819
# 369  | dynibar                        | Python     | 813
# 370  | flutter-provide                | Dart       | 804
# 371  | gps-measurement-tools          | Java       | 803
# 372  | quiche                         | C++        | 801
# 373  | nucleus                        | C++        | 797
# 374  | paranoid_crypto                | Python     | 796
# 375  | learned_optimization           | Python     | 788
# 376  | android-gradle-dsl             | HTML       | 785
# 377  | subcommands                    | Go         | 781
# 378  | dawn                           | C++        | 780
# 379  | turbinia                       | Python     | 777
# 380  | objax                          | Python     | 775
# 381  | cloud-print-connector          | Go         | 765
# 382  | goexpect                       | Go         | 758
# 383  | FluidNet                       | Lua        | 755
# 384  | brunsli                        | C++        | 745
# 385  | earthengine-community          | Jupyter Notebook | 744
# 386  | google-api-java-client-samples | Java       | 741
# 387  | ml-compiler-opt                | Python     | 737
# 388  | eng-edu                        | Jupyter Notebook | 734
# 389  | kctf                           | Go         | 731
# 390  | tachometer                     | TypeScript | 726
# 391  | simhospital                    | Go         | 717
# 392  | mobly                          | Python     | 716
# 393  | rerast                         | Rust       | 715
# 394  | compile-testing                | Java       | 715
# 395  | graph-mining                   | C++        | 712
# 396  | oauth2l                        | Go         | 709
# 397  | temporian                      | Python     | 703
# 398  | edward2                        | Jupyter Notebook | 702
# 399  | pyglove                        | Python     | 699
# 400  | clspv                          | LLVM       | 693
# 401  | transitfeed                    | Python     | 690
# 402  | startup-os                     | Java       | 687
# 403  | iconvg                         | C          | 682
# 404  | blockly-android                | Java       | 680
# 405  | ioweb2015                      | JavaScript | 680
# 406  | voice-builder                  | JavaScript | 679
# 407  | adk-web                        | TypeScript | 677
# 408  | closure-templates              | Java       | 671
# 409  | oss-rebuild                    | Go         | 670
# 410  | renameio                       | Go         | 667
# 411  | GoogleSignIn-iOS               | Objective-C | 667
# 412  | samba-documents-provider       | Java       | 666
# 413  | ml-metadata                    | C++        | 666
# 414  | horologist                     | Kotlin     | 658
# 415  | flatui                         | C++        | 651
# 416  | farmhash                       | C++        | 644
# 417  | santa-tracker-web              | JavaScript | 644
# 418  | svcca                          | Jupyter Notebook | 639
# 419  | libprotobuf-mutator            | C++        | 635
# 420  | cctz                           | C++        | 631
# 421  | playground-elements            | TypeScript | 627
# 422  | patents-public-data            | Jupyter Notebook | 627
# 423  | swift-jupyter                  | Python     | 623
# 424  | yggdrasil-decision-forests     | C++        | 622
# 425  | webauthndemo                   | TypeScript | 621
# 426  | go-tpm                         | Go         | 618
# 427  | project-gameface               | Java       | 617
# 428  | sqlcommenter                   | PHP        | 616
# 429  | openhtf                        | Python     | 614
# 430  | github-issue-mover             | Dart       | 612
# 431  | heir                           | C++        | 610
# 432  | libaddressinput                | C++        | 606
# 433  | gitiles                        | Java       | 603
# 434  | grain                          | Python     | 603
# 435  | graphicsfuzz                   | Java       | 595
# 436  | easypki                        | Go         | 593
# 437  | vim-maktaba                    | Vim Script | 589
# 438  | palette.js                     | JavaScript | 589
# 439  | seqio                          | Python     | 589
# 440  | u2f-ref-code                   | JavaScript | 588
# 441  | season-of-docs                 | Unknown    | 579
# 442  | s2-geometry-library-java       | Java       | 578
# 443  | qkeras                         | Python     | 578
# 444  | vulncode-db                    | Python     | 577
# 445  | libnop                         | C++        | 576
# 446  | autofdo                        | C++        | 576
# 447  | usd_from_gltf                  | C++        | 572
# 448  | android-fhir                   | Kotlin     | 571
# 449  | android-cuttlefish             | C++        | 571
# 450  | ktsan                          | Unknown    | 569
# 451  | subpar                         | Python     | 568
# 452  | module-server                  | JavaScript | 565
# 453  | protobuf.dart                  | Dart       | 558
# 454  | vpn-libraries                  | C++        | 554
# 455  | spherical-harmonics            | C++        | 552
# 456  | recki-ct                       | PHP        | 551
# 457  | search-samples                 | Java       | 549
# 458  | docker-explorer                | Python     | 548
# 459  | ukip                           | Python     | 546
# 460  | slo-generator                  | Python     | 546
# 461  | AEUX                           | JavaScript | 541
# 462  | paxml                          | Python     | 540
# 463  | tacotron                       | HTML       | 540
# 464  | personfinder                   | Python     | 540
# 465  | archive-patcher                | Java       | 540
# 466  | osv-scalibr                    | Go         | 538
# 467  | docsy-example                  | HTML       | 537
# 468  | CFU-Playground                 | Verilog    | 536
# 469  | google.github.io               | HTML       | 534
# 470  | private-compute-services       | Java       | 532
# 471  | schedviz                       | Go         | 530
# 472  | coding-with-chrome             | JavaScript | 530
# 473  | exposure-notifications-android | Java       | 529
# 474  | gke-policy-automation          | Go         | 525
# 475  | break-a-scene                  | Python     | 525
# 476  | cronet-transport-for-okhttp    | Java       | 523
# 477  | triage-party                   | Go         | 521
# 478  | ioweb2016                      | HTML       | 519
# 479  | mechahamster                   | C#         | 509
# 480  | clusterfuzzlite                | Unknown    | 509
# 481  | rustcxx                        | Rust       | 509
# 482  | mechahamster                   | C#         | 509
# 483  | transmat                       | TypeScript | 507
# 484  | react-schemaorg                | TypeScript | 506
# 485  | safeside                       | C++        | 505
# 486  | play-services-plugins          | Java       | 503
# 487  | dart-neats                     | Dart       | 503
# 488  | caliban                        | Python     | 500
# 489  | capillary                      | Java       | 500
# 490  | Accessibility-Test-Framework-for-Android | Java       | 499
# 491  | pybadges                       | Python     | 498
# 492  | crc32c                         | C++        | 498
# 493  | proto-lens                     | Haskell    | 497
# 494  | tf_mesh_renderer               | Python     | 497
# 495  | mannequinchallenge             | Python     | 496
# 496  | trace-viewer                   | Unknown    | 491
# 497  | cloud-forensics-utils          | Python     | 489
# 498  | safebrowsing                   | Go         | 488
# 499  | talkback                       | Java       | 488
# 500  | allocation-instrumenter        | Java       | 487
# 501  | licensecheck                   | Go         | 483
# 502  | cargo-raze                     | Rust       | 481
# 503  | adiantum                       | C          | 477
# 504  | gsocguides                     | CSS        | 475
# 505  | knusperli                      | C++        | 469
# 506  | kernel-sanitizers              | Python     | 468
# 507  | buzzer                         | Go         | 468
# 508  | h2e_technical_documentation    | Unknown    | 467
# 509  | play-unity-plugins             | C#         | 465
# 510  | riegeli                        | C++        | 465
# 511  | play-unity-plugins             | C#         | 465
# 512  | gmail-oauth2-tools             | Python     | 465
# 513  | shenzhen-go                    | JavaScript | 464
# 514  | walt                           | Java       | 462
# 515  | orbax                          | Python     | 455
# 516  | gtest-parallel                 | Python     | 454
# 517  | upvote_py2                     | Python     | 452
# 518  | snappy-start                   | C          | 450
# 519  | gdata-python-client            | HTML       | 450
# 520  | nerfactor                      | Python     | 449
# 521  | latency-benchmark              | C          | 446
# 522  | mug                            | Java       | 444
# 523  | gf180mcu-pdk                   | Makefile   | 442
# 524  | magritte                       | C++        | 441
# 525  | mediapy                        | Jupyter Notebook | 440
# 526  | data-layer-helper              | JavaScript | 440
# 527  | pienoon                        | C++        | 438
# 528  | speaker-id                     | Python     | 436
# 529  | music-synthesizer-for-android  | Jupyter Notebook | 434
# 530  | googlemock                     | Unknown    | 433
# 531  | go-replayers                   | Go         | 432
# 532  | clojure-turtle                 | Clojure    | 428
# 533  | bumble                         | Python     | 426
# 534  | digitalbuildings               | Python     | 425
# 535  | MOE                            | Java       | 422
# 536  | huproxy                        | Go         | 422
# 537  | go-microservice-helpers        | Go         | 418
# 538  | kmsan                          | C          | 417
# 539  | TestParameterInjector          | Java       | 415
# 540  | silifuzz                       | C++        | 413
# 541  | silifuzz                       | C++        | 413
# 542  | radioreceiver                  | JavaScript | 411
# 543  | uribeacon                      | Unknown    | 410
# 544  | blockly-ios                    | Swift      | 409
# 545  | ads-privacy                    | Unknown    | 408
# 546  | REAPER                         | C++        | 408
# 547  | googleapis.dart                | Dart       | 408
# 548  | stereo-magnification           | Python     | 406
# 549  | go-attestation                 | Go         | 406
# 550  | mcp-security                   | Python     | 404
# 551  | RB-Modulation                  | Jupyter Notebook | 402
# 552  | vimscript-language-server      | Rust       | 401
# 553  | gitprotocolio                  | Go         | 400
# 554  | kf                             | Go         | 400
# 555  | googletest-rust                | Rust       | 393
# 556  | aside                          | TypeScript | 392
# 557  | beacon-platform                | Unknown    | 391
# 558  | desugar_jdk_libs               | Java       | 389
# 559  | cameratrapai                   | Python     | 387
# 560  | etc2comp                       | C++        | 387
# 561  | language-resources             | C++        | 386
# 562  | hiba                           | C          | 384
# 563  | reflectable.dart               | Dart       | 382
# 564  | acme                           | Go         | 382
# 565  | aistplusplus_api               | Python     | 380
# 566  | mysql-ripple                   | C++        | 377
# 567  | syzygy                         | C++        | 377
# 568  | flutter_flux                   | Dart       | 376
# 569  | csp-evaluator                  | TypeScript | 374
# 570  | safehtml                       | Go         | 373
# 571  | vim-searchindex                | Vim Script | 369
# 572  | lifetime_value                 | Jupyter Notebook | 365
# 573  | fiddle                         | Python     | 364
# 574  | autobound                      | Python     | 363
# 575  | flaxformer                     | Python     | 363
# 576  | slang-gaussian-rasterization   | Python     | 362
# 577  | tie                            | JavaScript | 361
# 578  | pasta                          | Python     | 359
# 579  | CommonLoopUtils                | Jupyter Notebook | 358
# 580  | next-prediction                | Python     | 356
# 581  | deps.dev                       | Go         | 355
# 582  | revisiting-self-supervised     | Python     | 353
# 583  | blueprint                      | Go         | 352
# 584  | functional-objc                | Objective-C | 350
# 585  | making_with_ml                 | Jupyter Notebook | 348
# 586  | import-mailbox-to-gmail        | Python     | 346
# 587  | cpp-netlib                     | C++        | 344
# 588  | active-qa                      | Python     | 343
# 589  | vanir                          | Python     | 342
# 590  | minijail                       | C          | 342
# 591  | vector_math.dart               | Dart       | 341
# 592  | gcp_scanner                    | Python     | 341
# 593  | kafel                          | C          | 340
# 594  | closure-compiler-npm           | JavaScript | 339
# 595  | licenseclassifier              | Go         | 339
# 596  | ffn                            | Python     | 338
# 597  | pawn                           | C++        | 337
# 598  | randen                         | C++        | 337
# 599  | aqt                            | Python     | 337
# 600  | godepq                         | Go         | 335
# 601  | fplutil                        | Python     | 335
# 602  | godepq                         | Go         | 335
# 603  | paco                           | Objective-C | 332
# 604  | node-gles                      | C++        | 331
# 605  | esh                            | C          | 331
# 606  | perf_data_converter            | C++        | 331
# 607  | google-api-ruby-client-samples | Unknown    | 330
# 608  | dotprompt                      | Python     | 330
# 609  | node-h2-auto-push              | TypeScript | 328
# 610  | gwpsan                         | C++        | 327
# 611  | diffseg                        | Jupyter Notebook | 327
# 612  | smali                          | Java       | 325
# 613  | pepper.js                      | JavaScript | 324
# 614  | mentornet                      | Python     | 324
# 615  | password-alert                 | JavaScript | 322
# 616  | Xee                            | Python     | 321
# 617  | ldif                           | Python     | 320
# 618  | neper                          | C          | 318
# 619  | keep-sorted                    | Go         | 318
# 620  | VoltAir                        | C++        | 317
# 621  | ruy                            | C++        | 316
# 622  | ml-fairness-gym                | Python     | 316
# 623  | closure-stylesheets            | Java       | 315
# 624  | gnostic-grpc                   | Go         | 314
# 625  | fchan-go                       | Go         | 311
# 626  | thread-weaver                  | Java       | 309
# 627  | multibox                       | Unknown    | 307
# 628  | grr-doc                        | Shell      | 307
# 629  | alioth                         | Rust       | 307
# 630  | tirg                           | Python     | 304
# 631  | vimdoc                         | Python     | 304
# 632  | google-api-objectivec-client   | Unknown    | 303
# 633  | jni-bind                       | C++        | 303
# 634  | google-api-cpp-client          | C++        | 303
# 635  | portrait-shadow-manipulation   | Jupyter Notebook | 302
# 636  | dfiq                           | Python     | 294
# 637  | neural-logic-machines          | Python     | 293
# 638  | zooshi                         | C++        | 291
# 639  | wicked-good-xpath              | JavaScript | 289
# 640  | pprof-nodejs                   | JavaScript | 288
# 641  | google-visualization-issues    | Unknown    | 286
# 642  | hilbert                        | Go         | 286
# 643  | vxsig                          | C++        | 284
# 644  | built_collection.dart          | Dart       | 283
# 645  | kratu                          | JavaScript | 283
# 646  | gnxi                           | Python     | 282
# 647  | shaderc-rs                     | Rust       | 282
# 648  | EXEgesis                       | C++        | 281
# 649  | pyink                          | Python     | 280
# 650  | sagetv                         | Java       | 280
# 651  | learn_unsafe_rust              | Unknown    | 279
# 652  | cauliflowervest                | Python     | 278
# 653  | osqp-cpp                       | C++        | 277
# 654  | jpegli                         | C++        | 277
# 655  | neural-light-transport         | Python     | 277
# 656  | patchfield                     | Java       | 277
# 657  | cpp-from-the-sky-down          | HTML       | 276
# 658  | deepsomatic                    | Unknown    | 276
# 659  | psp                            | C          | 276
# 660  | jetpack-camera-app             | Kotlin     | 276
# 661  | vroom                          | Python     | 274
# 662  | chrome-ssh-agent               | Go         | 274
# 663  | ground-android                 | Kotlin     | 273
# 664  | go-tpm-tools                   | C          | 273
# 665  | shipshape                      | Go         | 270
# 666  | flutter-mediapipe              | Dart       | 270
# 667  | dynamic-video-depth            | Python     | 270
# 668  | casa-android                   | Kotlin     | 270
# 669  | vim-colorscheme-primary        | Vim Script | 268
# 670  | fedjax                         | Python     | 266
# 671  | grinder.dart                   | Dart       | 266
# 672  | google-input-tools             | JavaScript | 265
# 673  | gtm-session-fetcher            | Objective-C | 265
# 674  | mail-importer                  | Java       | 264
# 675  | libultrahdr                    | C++        | 264
# 676  | in-silico-labeling             | Python     | 262
# 677  | inverting-proxy                | Go         | 262
# 678  | uVkCompute                     | C++        | 257
# 679  | rust-crate-audits              | Unknown    | 255
# 680  | myanmar-tools                  | Java       | 255
# 681  | iosched-ios                    | Swift      | 254
# 682  | go-tika                        | Go         | 253
# 683  | centipede                      | Unknown    | 252
# 684  | slowjam                        | HTML       | 252
# 685  | deepconsensus                  | Python     | 252
# 686  | hat-backup                     | Rust       | 252
# 687  | path-auditor                   | C++        | 252
# 688  | corgi                          | C++        | 251
# 689  | vulkan-cpp-library             | C++        | 250
# 690  | ot-crdt-papers                 | JavaScript | 249
# 691  | der-ascii                      | Go         | 248
# 692  | burst-denoising                | Python     | 247
# 693  | flutter-stager                 | Dart       | 246
# 694  | etils                          | Python     | 244
# 695  | android-riscv64                | Unknown    | 242
# 696  | weather-tools                  | Python     | 241
# 697  | compact_enc_det                | C          | 239
# 698  | exposure-notifications-verification-server | Go         | 239
# 699  | cocoapods-size                 | Python     | 237
# 700  | ghost-userspace                | C          | 236
# 701  | lmeval                         | Python     | 235
# 702  | new-project                    | Unknown    | 234
# 703  | GTXiLib                        | Objective-C | 233
# 704  | prefab                         | Kotlin     | 229
# 705  | trajax                         | Python     | 228
# 706  | ci_edit                        | Python     | 228
# 707  | ground-platform                | TypeScript | 227
# 708  | ghost-kernel                   | C          | 227
# 709  | cel-java                       | Java       | 227
# 710  | restor                         | Objective-C | 226
# 711  | liblc3                         | C          | 225
# 712  | lipsync                        | JavaScript | 225
# 713  | rust-shell                     | Rust       | 225
# 714  | fuse-archive                   | C++        | 223
# 715  | imageinwords                   | JavaScript | 223
# 716  | git-appraise-web               | HTML       | 223
# 717  | explaining-in-style            | Jupyter Notebook | 223
# 718  | mount-zip                      | C++        | 221
# 719  | ffcc                           | MATLAB     | 217
# 720  | goterm                         | Go         | 216
# 721  | tcp_killer                     | Python     | 214
# 722  | extra-keyboards-for-chrome-os  | JavaScript | 214
# 723  | amber                          | C++        | 214
# 724  | android-key-attestation        | Java       | 213
# 725  | containerregistry              | Python     | 212
# 726  | sparrowhawk                    | Shell      | 212
# 727  | mysql-tools                    | Python     | 212
# 728  | corpuscrawler                  | Python     | 211
# 729  | transperf                      | Python     | 210
# 730  | region-flags                   | HTML       | 210
# 731  | capsicum-linux                 | C          | 210
# 732  | neural_rerendering_in_the_wild | Python     | 208
# 733  | supersonic                     | C++        | 207
# 734  | open-vcdiff                    | C++        | 205
# 735  | cel-cpp                        | C++        | 205
# 736  | e3d_lstm                       | Python     | 205
# 737  | fhir-data-pipes                | Jupyter Notebook | 204
# 738  | bazel-to-cmake                 | Python     | 204
# 739  | tree-math                      | Python     | 203
# 740  | pack                           | Rust       | 203
# 741  | motive                         | C++        | 202
# 742  | opendocs                       | Unknown    | 199
# 743  | minja                          | C++        | 198
# 744  | fplbase                        | C++        | 198
# 745  | ipaddr-py                      | Python     | 195
# 746  | devlibrary                     | Vue        | 194
# 747  | go-flow-levee                  | Go         | 194
# 748  | mdbook-i18n-helpers            | Rust       | 194
# 749  | tuple.dart                     | Dart       | 194
# 750  | starlark-rust                  | Unknown    | 193
# 751  | CodeCity                       | JavaScript | 193
# 752  | canvas-5-polyfill              | JavaScript | 192
# 753  | libcxx                         | C++        | 192
# 754  | praxis                         | Python     | 190
# 755  | shlex                          | Go         | 190
# 756  | vpn-reverse-tether             | C          | 190
# 757  | gonids                         | Go         | 189
# 758  | marmot                         | Go         | 189
# 759  | python-gflags                  | Python     | 188
# 760  | integers                       | C++        | 188
# 761  | sre_yield                      | Python     | 187
# 762  | php-crc32                      | PHP        | 186
# 763  | gdata-objectivec-client        | Objective-C | 186
# 764  | todo-tracks                    | Go         | 185
# 765  | glance-experimental-tools      | Kotlin     | 185
# 766  | instant-hangouts               | JavaScript | 184
# 767  | dnsmasq_exporter               | Go         | 183
# 768  | service-worker-detector        | JavaScript | 183
# 769  | cppdap                         | C++        | 182
# 770  | pcbdl                          | Python     | 182
# 771  | js-green-licenses              | TypeScript | 181
# 772  | goblet                         | Go         | 181
# 773  | go-cmdtest                     | Go         | 180
# 774  | tensorflow-recorder            | Python     | 180
# 775  | virtual-authenticators-tab     | JavaScript | 179
# 776  | vae-seq                        | Python     | 177
# 777  | TrustScore                     | Jupyter Notebook | 177
# 778  | importlab                      | Python     | 177
# 779  | eDistantObject                 | Objective-C | 176
# 780  | retiming                       | Python     | 176
# 781  | eDistantObject                 | Objective-C | 176
# 782  | scaaml                         | Python     | 175
# 783  | inspectorspacetime             | JavaScript | 175
# 784  | encrypted-bigquery-client      | Python     | 175
# 785  | evolve-forms                   | Apex       | 175
# 786  | minimalloc                     | C++        | 175
# 787  | gcnn-survey-paper              | Python     | 174
# 788  | python-subprocess32            | Python     | 173
# 789  | trillian-examples              | Go         | 173
# 790  | starthinker                    | Python     | 173
# 791  | node-sec-roadmap               | JavaScript | 173
# 792  | zimtohrli                      | Jupyter Notebook | 173
# 793  | osdfir-infrastructure          | Smarty     | 172
# 794  | lasr                           | Python     | 172
# 795  | kasane                         | Python     | 172
# 796  | detangle                       | JavaScript | 171
# 797  | ctfscoreboard                  | Python     | 171
# 798  | dimsum                         | C++        | 171
# 799  | llvm-bazel                     | Starlark   | 170
# 800  | loaner                         | Python     | 170
# 801  | turing-doodle                  | JavaScript | 170
# 802  | cluster-scheduler-simulator    | Scala      | 170
# 803  | classp                         | Bison      | 169
# 804  | data-driven-discretization-1d  | Jupyter Notebook | 168
# 805  | crumsort-rs                    | Rust       | 168
# 806  | moveit                         | Rust       | 168
# 807  | elemental2                     | Java       | 167
# 808  | automotive-design-compose      | Rust       | 167
# 809  | googlesre                      | TypeScript | 167
# 810  | render-timing-for-unity        | C++        | 167
# 811  | oss-fuzz-vulns                 | Python     | 166
# 812  | LiquidFunPaint                 | Java       | 166
# 813  | googletv-android-samples       | Java       | 165
# 814  | uniflow-polymer                | HTML       | 165
# 815  | fancy-regex                    | Rust       | 165
# 816  | mono_repo.dart                 | Dart       | 165
# 817  | lecam-gan                      | Jupyter Notebook | 165
# 818  | travel-impact-model            | Unknown    | 164
# 819  | dart-basics                    | Dart       | 164
# 820  | zetasketch                     | Java       | 163
# 821  | security-crawl-maze            | HTML       | 163
# 822  | apis-client-generator          | Python     | 162
# 823  | postcss-rename                 | TypeScript | 162
# 824  | redgrep                        | C++        | 162
# 825  | x-amber                        | C          | 162
# 826  | vim-jsonnet                    | Vim Script | 161
# 827  | chicago-brick                  | TypeScript | 161
# 828  | xr-objects                     | C#         | 161
# 829  | knative-gcp                    | Go         | 161
# 830  | gwtmockito                     | Java       | 160
# ...
# 2527 | jenkins-flaky-test-report      | Unknown    | 5
# 2528 | coursebuilder-learning-analytics | Unknown    | 5
# 2529 | go-glicko2                     | Unknown    | 5
# 2530 | gin                            | Unknown    | 5
# 2531 | go-shlex                       | Unknown    | 5
# 2532 | citizen-x                      | Unknown    | 5
# 2533 | network-visualizer-x           | Unknown    | 5
# 2534 | auto-factory                   | Unknown    | 5
# 2535 | auto-service                   | Unknown    | 5
# 2536 | auto-common                    | Unknown    | 5
# 2537 | dev-on-chromeos-che            | Unknown    | 5
# 2538 | standard-payments              | Unknown    | 5
# 2539 | cloud-network-reachability     | Unknown    | 5
# 2540 | skywater-pdk-libs-sky90fd_fd_sc | Unknown    | 5
# 2541 | asml                           | Unknown    | 5
# 2542 | task-oriented-queries          | Unknown    | 5
# 2543 | gfbuild-amber                  | Shell      | 5
# 2544 | cornerstoneTools               | JavaScript | 5
# 2545 | cornerstoneWebImageLoader      | JavaScript | 5
# 2546 | cornerstoneWADOImageLoader     | JavaScript | 5
# 2547 | sa360-bulk-editor              | JavaScript | 5
# 2548 | vapso                          | JavaScript | 5
# 2549 | trueview-sdf-generator         | JavaScript | 5
# 2550 | cm-user-tool                   | JavaScript | 5
# 2551 | wikiloop-wikidata-game         | JavaScript | 5
# 2552 | sa360-bidbyweather             | JavaScript | 5
# 2553 | dv-3po                         | JavaScript | 5
# 2554 | recog                          | JavaScript | 5
# 2555 | talos-dv360                    | JavaScript | 5
# 2556 | budget-protector               | JavaScript | 5
# 2557 | ad_language_monitor            | JavaScript | 5
# 2558 | drive-file-search-fix          | JavaScript | 5
# 2559 | swift-llbuild                  | C++        | 5
# 2560 | protodatastore-cpp             | C++        | 5
# 2561 | http_pattern_matcher           | C++        | 5
# 2562 | gsrsup                         | C++        | 5
# 2563 | cairn                          | C++        | 5
# 2564 | foteli                         | C++        | 5
# 2565 | imt                            | C++        | 5
# 2566 | io-captions-gadget             | Python     | 5
# 2567 | repose                         | Python     | 5
# 2568 | rescue-tools-reiserfs          | Python     | 5
# 2569 | structured_labels              | Python     | 5
# 2570 | blockbuster                    | Python     | 5
# 2571 | deluca-lung                    | Python     | 5
# 2572 | adh-deployment-manager         | Python     | 5
# 2573 | Vulkan-Errata                  | Python     | 5
# 2574 | html-to-jsonld-converter       | Python     | 5
# 2575 | mobly-android-screen-recorder  | Python     | 5
# 2576 | mobly-bluetooth-ref-validation | Python     | 5
# 2577 | bt-navi-tests                  | Python     | 5
# 2578 | swift-cmark                    | C          | 5
# 2579 | swift-compiler-rt              | C          | 5
# 2580 | swift-corelibs-foundation      | C          | 5
# 2581 | swift-corelibs-libdispatch     | C          | 5
# 2582 | eiffel                         | C          | 5
# 2583 | pods-helper                    | Objective-C | 5
# 2584 | ytstatistics-demo              | Java       | 5
# 2585 | wear-displaylock               | Java       | 5
# 2586 | opentest4j                     | Java       | 5
# 2587 | sha1dc-jni                     | Java       | 5
# 2588 | java-run                       | Java       | 5
# 2589 | app-metadata-encoder           | Java       | 5
# 2590 | unity-anr-plugin               | Java       | 5
# 2591 | crumbles                       | Java       | 5
# 2592 | fast-optimized-community-significance | R          | 5
# 2593 | skywater-pdk-libs-sky130_fd_sc_hs | Verilog    | 5
# 2594 | skywater-pdk-libs-sky130_fd_sc_ms | Verilog    | 5
# 2595 | skywater-pdk-libs-sky130_fd_sc_ls | Verilog    | 5
# 2596 | grr_go_api_client              | Go         | 5
# 2597 | grr_go_client                  | Go         | 5
# 2598 | gcb-tools                      | Go         | 5
# 2599 | ORFConverter                   | C#         | 5
# 2600 | receipts-to-riches-part1       | C#         | 5
# 2601 | decoder-benchmarks-for-rust    | Rust       | 5
# 2602 | secure-aggregation             | Rust       | 5
# 2603 | librato.dart                   | Dart       | 5
# 2604 | conversion-audit               | TypeScript | 5
# 2605 | travel-impact-model-website    | TypeScript | 5
# 2606 | vscode-vnc                     | TypeScript | 5
# 2607 | swift-corelibs-xctest          | Swift      | 5
# 2608 | dropzone-polyfill              | HTML       | 5
# 2609 | chive-prosody                  | HTML       | 5
# 2610 | controlled-noisy-web-labels    | HTML       | 5
# 2611 | deepmac                        | HTML       | 5
# 2612 | look-before-you-speak          | HTML       | 5
# 2613 | polynomial-practice            | HTML       | 5
# 2614 | gdal-autotest2                 | Unknown    | 4
# 2615 | photo-sphere                   | Unknown    | 4
# 2616 | deliberate                     | Unknown    | 4
# 2617 | older-mirrored-patches         | Unknown    | 4
# 2618 | gitwf                          | Unknown    | 4
# 2619 | sass_generator                 | Unknown    | 4
# 2620 | git-annex-external-gcs         | Unknown    | 4
# 2621 | river                          | Unknown    | 4
# 2622 | node-armor                     | Unknown    | 4
# 2623 | fleetspeak-doc                 | Unknown    | 4
# 2624 | HardwarePrototypingToolkit     | Unknown    | 4
# 2625 | x                              | Unknown    | 4
# 2626 | overcoming-conflicting-data    | Unknown    | 4
# 2627 | skywater-pdk-libs-sky90fd_osu_sc | Unknown    | 4
# 2628 | skywater-pdk-libs-sky90fd_fd_io | Unknown    | 4
# 2629 | partner-ads-experience         | Unknown    | 4
# 2630 | deshell                        | Unknown    | 4
# 2631 | saif-data                      | Unknown    | 4
# 2632 | myvibe                         | Unknown    | 4
# 2633 | param_runner                   | Shell      | 4
# 2634 | backup-dr-custom-roles         | Shell      | 4
# 2635 | premium-vs-standard-network-latency | Shell      | 4
# 2636 | node-nest                      | JavaScript | 4
# 2637 | gulp-google-closure-deps       | JavaScript | 4
# 2638 | CurbsidePickup                 | JavaScript | 4
# 2639 | outrigger                      | JavaScript | 4
# 2640 | custom-tab-groups              | JavaScript | 4
# 2641 | step197-2020                   | Java       | 4
# 2642 | peg-typed                      | Kotlin     | 4
# 2643 | outrigger                      | JavaScript | 4
# 2644 | x                              | Unknown    | 4
# 2645 | overcoming-conflicting-data    | Unknown    | 4
# 2646 | xscreensaver-dbus              | Haskell    | 4
# 2647 | skywater-pdk-libs-sky130_fd_sc_hvl | Verilog    | 4
# 2648 | custom-tab-groups              | JavaScript | 4
# 2649 | cpp-proto-builder              | C++        | 4
# 2650 | vscode-zxdb                    | TypeScript | 4
# 2651 | hs-dependent-literals          | Haskell    | 4
# 2652 | hs-ten                         | Haskell    | 4
# 2653 | nsc-tutorial                   | Jupyter Notebook | 4
# 2654 | trusted-worklet-server         | C++        | 4
# 2655 | android-cuttlefish-authentication | Python     | 4
# 2656 | phoneme-aligned-graphemes-in-tts | HTML       | 4
# 2657 | postcss-src                    | TypeScript | 4
# 2658 | exists-ref                     | Rust       | 4
# 2659 | sxg-validator                  | JavaScript | 4
# 2660 | nanopb-cpputest-comparators    | C++        | 4
# 2661 | draft-todo-chariton-dns-account-01 | Dockerfile | 4
# 2662 | backup-dr-custom-roles         | Shell      | 4
# 2663 | pmax_migration                 | Python     | 4
# 2664 | skywater-pdk-libs-sky90fd_osu_sc | Unknown    | 4
# 2665 | skywater-pdk-libs-sky90fd_fd_io | Unknown    | 4
# 2666 | rtb_creative_filtering_report  | TypeScript | 4
# 2667 | uafcs                          | Python     | 4
# 2668 | traceviz                       | TypeScript | 4
# 2669 | mpact-sim-codelabs             | C++        | 4
# 2670 | partner-ads-experience         | Unknown    | 4
# 2671 | page-alloc-bench               | Go         | 4
# 2672 | cc-device-plugin               | Go         | 4
# 2673 | exists-ref                     | Rust       | 4
# 2674 | ippusb                         | Rust       | 4
# 2675 | pts-bot                        | Rust       | 4
# 2676 | peg-typed                      | Kotlin     | 4
# 2677 | intellij-kotlin                | Kotlin     | 4
# 2678 | vscode-zxdb                    | TypeScript | 4
# 2679 | postcss-src                    | TypeScript | 4
# 2680 | rtb_creative_filtering_report  | TypeScript | 4
# 2681 | traceviz                       | TypeScript | 4
# 2682 | search-in-apps                 | Swift      | 4
# 2683 | speech_style_transfer          | HTML       | 4
# 2684 | phase-prediction               | HTML       | 4
# 2685 | StrawNet                       | HTML       | 4
# 2686 | phoneme-aligned-graphemes-in-tts | HTML       | 4
# 2687 | nsc-tutorial                   | Jupyter Notebook | 4
# 2688 | draft-todo-chariton-dns-account-01 | Dockerfile | 4
# 2689 | jsontoken-tmp                  | Unknown    | 3
# 2690 | reboot-somalia                 | Unknown    | 3
# 2691 | organ-donor-app                | Unknown    | 3
# 2692 | xpra-upstart                   | Unknown    | 3
# 2693 | physical-web-core              | Unknown    | 3
# 2694 | google-empty-test-module       | Unknown    | 3
# 2695 | opentest                       | Unknown    | 3
# 2696 | gfbuild-SPIRV-Cross            | Unknown    | 3
# 2697 | icing-search                   | Unknown    | 3
# 2698 | cloud-network-reachabilty      | Unknown    | 3
# 2699 | or-models                      | Unknown    | 3
# 2700 | sonic-p4rt                     | Unknown    | 3
# 2701 | fhir-ml                        | Unknown    | 3
# 2702 | devsite-template               | Unknown    | 3
# 2703 | fledge-key-value-server        | Unknown    | 3
# 2704 | closure-net                    | Unknown    | 3
# 2705 | skcms                          | Unknown    | 3
# 2706 | gfbuild-shadertrap             | Shell      | 3
# 2707 | profit-bidder                  | Shell      | 3
# 2708 | java-video-live-stream         | Shell      | 3
# 2709 | amot                           | Shell      | 3
# 2710 | videotts                       | JavaScript | 3
# 2711 | baby-alligator                 | JavaScript | 3
# 2712 | trusted-key-value-server       | C++        | 3
# 2713 | process-tree                   | C++        | 3
# 2714 | loudness_ebur128               | C++        | 3
# 2715 | image-supplemental-feed-creator | Python     | 3
# 2716 | distla_core                    | Python     | 3
# 2717 | parallel_accel                 | Python     | 3
# 2718 | memutil                        | Python     | 3
# 2719 | mint-line-follower             | Python     | 3
# 2720 | xssxss                         | C          | 3
# 2721 | testrunner-rosemary            | Java       | 3
# 2722 | step49-2020                    | Java       | 3
# 2723 | zero-touch-reseller-tool       | Java       | 3
# 2724 | floody                         | Java       | 3
# 2725 | snowflake-to-bq-data-transfer-tool | Java       | 3
# 2726 | hs-attenuation                 | Haskell    | 3
# 2727 | hs-batching                    | Haskell    | 3
# 2728 | hs-collate                     | Haskell    | 3
# 2729 | hs-fin-vec                     | Haskell    | 3
# 2730 | hs-numeric-logarithms          | Haskell    | 3
# 2731 | memutil                        | Python     | 3
# 2732 | process-tree                   | C++        | 3
# 2733 | closure-net                    | Unknown    | 3
# 2734 | mint-line-follower             | Python     | 3
# 2735 | game-changing-assets           | Jupyter Notebook | 3
# 2736 | docci                          | HTML       | 3
# 2737 | terraform-google-sqlserver     | PowerShell | 3
# 2738 | funke-eudi-wallet-prototype    | Kotlin     | 3
# 2739 | play-core-unity                | C#         | 3
# 2740 | play-in-app-updates-unity      | C#         | 3
# 2741 | ionosphere                     | Jupyter Notebook | 3
# 2742 | loudness_ebur128               | C++        | 3
# 2743 | iwa-vscode-extension           | TypeScript | 3
# 2744 | skcms                          | Unknown    | 3
# 2745 | async-request-dispatcher-rs    | Rust       | 3
# 2746 | YouCompleteSubl                | Unknown    | 2
# 2747 | ts-gulp                        | Unknown    | 2
# 2748 | rtb_troubleshooting_connector  | JavaScript | 2
# 2749 | longt5                         | Unknown    | 2
# 2750 | stable-retraining-conversational-agents | Unknown    | 2
# 2751 | csv2pprof                      | Go         | 2
# 2752 | dsg                            | HTML       | 2
# 2753 | gdb_gcore_point                | Python     | 2
# 2754 | spdm-accelerator-requirement   | Unknown    | 2
# 2755 | osv-scanner-v1                 | Go         | 2
# 2756 | how-unique-is-whose-web-browser | Jupyter Notebook | 2
# 2757 | gcp-scc-iac-validation-utils   | Go         | 2
# 2758 | price_visibility_booster       | JavaScript | 2
# 2759 | webdriver-shadow-dom           | Kotlin     | 2
# 2760 | oxsea                          | Rust       | 2
# 2761 | csv2pprof                      | Go         | 2
# 2762 | osv-scanner-v1                 | Go         | 2
# 2763 | gcp-scc-iac-validation-utils   | Go         | 2
# 2764 | sbom-conformance               | Go         | 2
# 2765 | quahog                         | Go         | 2
# 2766 | oxsea                          | Rust       | 2
# 2767 | lottie-tools                   | Rust       | 2
# 2768 | flyweights                     | Rust       | 2
# 2769 | webdriver-shadow-dom           | Kotlin     | 2
# 2770 | virtual-printer                | Kotlin     | 2
# 2771 | dsg                            | HTML       | 2
# 2772 | how-unique-is-whose-web-browser | Jupyter Notebook | 2
# 2773 | google-cloud-datastore-quadruple | M4         | 2
# 2774 | where-is-my-watch              | Unknown    | 1
# 2775 | usm-voice-transcriber          | Unknown    | 1
# 2776 | cmrt                           | Unknown    | 1
# 2777 | ragvis                         | Unknown    | 1
# 2778 | iba-opt-out-plugin             | JavaScript | 1
# 2779 | dlc-insight-lab                | JavaScript | 1
# 2780 | proto-splitter                 | C++        | 1
# 2781 | p4-infra                       | C++        | 1
# 2782 | rde-tester                     | C++        | 1
# 2783 | ic-modeling-python             | Python     | 1
# 2784 | symphony-gcp                   | Python     | 1
# 2785 | dmabuf_importer_helper         | C          | 1
# 2786 | smc-common                     | C          | 1
# 2787 | smc-hello-world                | C          | 1
# 2788 | appengine-java-migration-samples | Java       | 1
# 2789 | taxinomia                      | Go         | 1
# 2790 | yarsa                          | Go         | 1
# 2791 | receipts-to-riches-part2       | C#         | 1
# 2792 | play-common-unity              | C#         | 1
# 2793 | casimir                        | Rust       | 1
# 2794 | synopsys-dw-uart               | Rust       | 1
# 2795 | bulk-actions-framework         | Apex       | 1
# 2796 | tweakr-codelab                 | Kotlin     | 1
# 2797 | sso-offloading                 | TypeScript | 1
# 2798 | filament-assets                | Mathematica | 1
# 2799 | unblocking-detail-caption      | HTML       | 1
# 2800 | webview-ads                    | HTML       | 1
# 2801 | alu-api                        | Jupyter Notebook | 1
# 2802 | common-multicloud-runtime      | Unknown    | 0
# 2803 | s2a-proto                      | Unknown    | 0
# 2804 | automotive-design-compose-protos | Unknown    | 0
# 2805 | distributed_graph_flow         | Unknown    | 0
# 2806 | graph-renderer                 | Unknown    | 0
# 2807 | refvnli                        | JavaScript | 0
# 2808 | spdmd                          | C++        | 0
# 2809 | gurl                           | C++        | 0
# 2810 | capsem                         | Python     | 0
# 2811 | soql-tool                      | Apex       | 0
# 2812 | codeql-action                  | TypeScript | 0
# データが見つかりませんでした。終了します。
# ------------------------------------------------------------
# 完了: 合計 2812 件取得しました。

# %% [markdown]
# ## DBへ保存

# %%
import sqlite3

def save_to_db(data):
    if not data:
        print("保存するデータがありません。")
        return

    # データベース名
    dbname = 'google_repos.db'
    
    # 接続
    conn = sqlite3.connect(dbname)
    cur = conn.cursor()

    # テーブルの初期化
    cur.execute('DROP TABLE IF EXISTS repositories')
    
    # テーブル作成
    cur.execute('''
        CREATE TABLE repositories (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            name TEXT,
            language TEXT,
            stars TEXT
        )
    ''')

    # データの挿入
    cur.executemany('INSERT INTO repositories (name, language, stars) VALUES (?, ?, ?)', data)

    # 保存を確定して閉じる
    conn.commit()
    conn.close()

    print(f"保存件数: {len(data)} 件")

# 実行
save_to_db(scraped_data)
# Out:
# 保存件数: 2812 件

# %% [markdown]
# ## SELECT文

# %%
def show_data():
    dbname = 'google_repos.db'
    conn = sqlite3.connect(dbname)
    cur = conn.cursor()

    print("\n--- データベースの中身を確認します ---")
    
    # 全データを取得して表示
    cur.execute('SELECT * FROM repositories')
    rows = cur.fetchall()

    if not rows:
        print("データがありません。")
    else:
        print(f"{'ID':<4} | {'リポジトリ名':<30} | {'言語':<10} | {'スター数'}")
        print("-" * 65)
        for row in rows:
            # rowは (id, name, language, stars) のタプルになっています
            print(f"{row[0]:<4} | {row[1]:<30} | {row[2]:<10} | {row[3]}")

    conn.close()

# 保存の実行
save_to_db(scraped_data)

# 表示の実行
show_data()
# Out:
# 保存件数: 2812 件
#
# --- データベースの中身を確認します ---
# ID   | リポジトリ名                         | 言語         | スター数
# -----------------------------------------------------------------
# 1    | material-design-icons          | Unknown    | 53k
# 2    | guava                          | Java       | 51k
# 3    | zx                             | JavaScript | 45k
# 4    | styleguide                     | HTML       | 39k
# 5    | leveldb                        | C++        | 38k
# 6    | googletest                     | C++        | 38k
# 7    | comprehensive-rust             | Rust       | 32k
# 8    | material-design-lite           | HTML       | 32k
# 9    | python-fire                    | Python     | 28k
# 10   | flatbuffers                    | C++        | 25k
# 11   | gson                           | Java       | 24k
# 12   | ExoPlayer                      | Java       | 22k
# 13   | iosched                        | Kotlin     | 22k
# 14   | eng-practices                  | Unknown    | 20k
# 15   | fonts                          | HTML       | 19k
# 16   | filament                       | C++        | 19k
# 17   | cadvisor                       | Go         | 19k
# 18   | web-starter-kit                | HTML       | 18k
# 19   | flexbox-layout                 | Kotlin     | 18k
# 20   | libphonenumber                 | C++        | 18k
# 21   | dagger                         | Java       | 18k
# 22   | gvisor                         | Go         | 17k
# 23   | langextract                    | Python     | 17k
# 24   | adk-python                     | Python     | 16k
# 25   | brotli                         | TypeScript | 14k
# 26   | wire                           | Go         | 14k
# 27   | yapf                           | Python     | 14k
# 28   | WebFundamentals                | JavaScript | 14k
# 29   | deepdream                      | Unknown    | 13k
# 30   | guetzli                        | C++        | 13k
# 31   | or-tools                       | C++        | 13k
# 32   | guice                          | Java       | 13k
# 33   | sanitizers                     | C          | 12k
# 34   | oss-fuzz                       | Shell      | 12k
# 35   | sentencepiece                  | C++        | 11k
# 36   | go-github                      | Go         | 11k
# 37   | dopamine                       | Jupyter Notebook | 11k
# 38   | auto                           | Java       | 11k
# 39   | grumpy                         | Go         | 11k
# 40   | skia                           | C++        | 10k
# 41   | benchmark                      | C++        | 9.9k
# 42   | magika                         | Python     | 9.8k
# 43   | go-cloud                       | Go         | 9.8k
# 44   | re2                            | C++        | 9.5k
# 45   | pprof                          | Go         | 8.9k
# 46   | tsunami-security-scanner       | Java       | 8.5k
# 47   | trax                           | Python     | 8.3k
# 48   | traceur-compiler               | JavaScript | 8.2k
# 49   | osv-scanner                    | Go         | 8.1k
# 50   | diff-match-patch               | Python     | 8k
# 51   | accompanist                    | Kotlin     | 7.8k
# 52   | model-viewer                   | TypeScript | 7.7k
# 53   | closure-compiler               | JavaScript | 7.6k
# 54   | android-classyshark            | Java       | 7.6k
# 55   | latexify_py                    | Python     | 7.6k
# 56   | jsonnet                        | Jsonnet    | 7.4k
# 57   | glog                           | C++        | 7.3k
# 58   | agera                          | Java       | 7.2k
# 59   | error-prone                    | Java       | 7.1k
# 60   | flutter-desktop-embedding      | C++        | 7.1k
# 61   | draco                          | C++        | 7k
# 62   | gops                           | Go         | 7k
# 63   | flax                           | Jupyter Notebook | 6.9k
# 64   | lovefield                      | JavaScript | 6.8k
# 65   | gopacket                       | Go         | 6.7k
# 66   | gemma.cpp                      | C++        | 6.6k
# 67   | snappy                         | C++        | 6.5k
# 68   | adk-samples                    | Python     | 6.5k
# 69   | automl                         | Jupyter Notebook | 6.4k
# 70   | wireit                         | TypeScript | 6.3k
# 71   | grafika                        | Java       | 6.1k
# 72   | ios-webkit-debug-proxy         | C          | 6.1k
# 73   | j2objc                         | Java       | 6k
# 74   | physical-web                   | Java       | 6k
# 75   | google-java-format             | Java       | 6k
# 76   | syzkaller                      | Go         | 5.9k
# 77   | uuid                           | Go         | 5.9k
# 78   | bbr                            | Unknown    | 5.8k
# 79   | seesaw                         | Go         | 5.7k
# 80   | EarlGrey                       | Objective-C | 5.7k
# 81   | seq2seq                        | Python     | 5.6k
# 82   | gemma_pytorch                  | Python     | 5.6k
# 83   | clusterfuzz                    | Python     | 5.5k
# 84   | battery-historian              | Go         | 5.4k
# 85   | clasp                          | TypeScript | 5.3k
# 86   | google-authenticator           | Java       | 5.3k
# 87   | bloaty                         | C++        | 5.3k
# 88   | git-appraise                   | Go         | 5.3k
# 89   | gts                            | TypeScript | 5.2k
# 90   | gumbo-parser                   | HTML       | 5.2k
# 91   | highway                        | C++        | 5.1k
# 92   | tf-quant-finance               | Python     | 5.1k
# 93   | pytype                         | Python     | 5k
# 94   | perfetto                       | C++        | 5k
# 95   | tcmalloc                       | C++        | 5k
# 96   | grr                            | Python     | 5k
# 97   | pebble                         | C          | 4.9k
# 98   | closure-library                | JavaScript | 4.9k
# 99   | liquidfun                      | C++        | 4.9k
# 100  | google-ctf                     | Python     | 4.8k
# 101  | adk-go                         | Go         | 4.8k
# 102  | cameraview                     | Java       | 4.7k
# 103  | wuffs                          | C          | 4.7k
# 104  | go-cmp                         | Go         | 4.5k
# 105  | santa                          | Objective-C++ | 4.5k
# 106  | gxui                           | Go         | 4.4k
# 107  | orbit                          | C++        | 4.3k
# 108  | open-location-code             | Java       | 4.3k
# 109  | security-research              | C          | 4.3k
# 110  | tamperchrome                   | TypeScript | 4.2k
# 111  | btree                          | Go         | 4.1k
# 112  | end-to-end                     | JavaScript | 4.1k
# 113  | eleventy-high-performance-blog | JavaScript | 4.1k
# 114  | AFL                            | C          | 4k
# 115  | mtail                          | Go         | 4k
# 116  | oboe                           | C++        | 4k
# 117  | lyra                           | C++        | 3.9k
# 118  | bundletool                     | Java       | 3.9k
# 119  | codesearch                     | Go         | 3.9k
# 120  | angle                          | C++        | 3.8k
# 121  | promises                       | Objective-C | 3.8k
# 122  | fuzzing                        | C++        | 3.7k
# 123  | rejoiner                       | Java       | 3.7k
# 124  | trillian                       | Go         | 3.7k
# 125  | fully-homomorphic-encryption   | C++        | 3.6k
# 126  | go-containerregistry           | Go         | 3.6k
# 127  | tarpc                          | Rust       | 3.6k
# 128  | nsjail                         | C++        | 3.6k
# 129  | deepvariant                    | Python     | 3.6k
# 130  | zopfli                         | C++        | 3.6k
# 131  | incremental-dom                | TypeScript | 3.5k
# 132  | recaptcha                      | PHP        | 3.5k
# 133  | cel-spec                       | Starlark   | 3.5k
# 134  | google-api-javascript-client   | CSS        | 3.4k
# 135  | robotstxt                      | C++        | 3.4k
# 136  | volley                         | Java       | 3.4k
# 137  | prompt-to-prompt               | Jupyter Notebook | 3.4k
# 138  | lmctfy                         | C++        | 3.4k
# 139  | cdc-file-transfer              | C++        | 3.4k
# 140  | skywater-pdk                   | Python     | 3.3k
# 141  | ksp                            | Kotlin     | 3.3k
# 142  | bottery                        | JavaScript | 3.3k
# 143  | honggfuzz                      | C          | 3.3k
# 144  | model_search                   | Python     | 3.3k
# 145  | differential-privacy           | Go         | 3.3k
# 146  | OpenSK                         | Rust       | 3.2k
# 147  | timesketch                     | Python     | 3.2k
# 148  | lisp-koans                     | Common Lisp | 3.2k
# 149  | BIG-bench                      | Python     | 3.2k
# 150  | earthengine-api                | JavaScript | 3.1k
# 151  | netstack                       | Go         | 3.1k
# 152  | eddystone                      | C          | 3.1k
# 153  | gif-for-cli                    | Python     | 2.9k
# 154  | nogotofail                     | Python     | 2.9k
# 155  | brax                           | Jupyter Notebook | 2.9k
# 156  | binnavi                        | Java       | 2.9k
# 157  | docsy                          | JavaScript | 2.9k
# 158  | mangle                         | Go         | 2.9k
# 159  | breakpad                       | C++        | 2.8k
# 160  | bindiff                        | Java       | 2.8k
# 161  | charts                         | Dart       | 2.8k
# 162  | cel-go                         | Go         | 2.8k
# 163  | truth                          | Java       | 2.8k
# 164  | mozc                           | C++        | 2.8k
# 165  | enjarify                       | Python     | 2.7k
# 166  | earthenterprise                | C++        | 2.7k
# 167  | mozc-devices                   | C++        | 2.7k
# 168  | forma                          | Rust       | 2.6k
# 169  | tracing-framework              | JavaScript | 2.6k
# 170  | hover                          | Java       | 2.6k
# 171  | omaha                          | C++        | 2.6k
# 172  | starlark-go                    | Go         | 2.6k
# 173  | cpu_features                   | C++        | 2.6k
# 174  | exposure-notifications-server  | Go         | 2.6k
# 175  | s2geometry                     | C++        | 2.6k
# 176  | jimfs                          | Java       | 2.5k
# 177  | copybara                       | Java       | 2.5k
# 178  | autocxx                        | Rust       | 2.5k
# 179  | zetasql                        | C++        | 2.4k
# 180  | swiftshader                    | C++        | 2.4k
# 181  | osv.dev                        | Python     | 2.4k
# 182  | youtube-8m                     | Python     | 2.4k
# 183  | neural-tangents                | Jupyter Notebook | 2.4k
# 184  | tangent                        | Python     | 2.3k
# 185  | souper                         | C++        | 2.3k
# 186  | gnostic                        | Go         | 2.2k
# 187  | gapid                          | Go         | 2.2k
# 188  | ngx_brotli                     | C          | 2.2k
# 189  | generative-ai-docs             | Jupyter Notebook | 2.2k
# 190  | XNNPACK                        | C          | 2.2k
# 191  | marzipano                      | JavaScript | 2.2k
# 192  | mathsteps                      | JavaScript | 2.1k
# 193  | gin-config                     | Python     | 2.1k
# 194  | go-querystring                 | Go         | 2.1k
# 195  | zerocopy                       | Rust       | 2.1k
# 196  | santa-tracker-android          | Java       | 2.1k
# 197  | shaderc                        | C++        | 2.1k
# 198  | boringssl                      | C++        | 2.1k
# 199  | martian                        | Go         | 2k
# 200  | android-emulator-container-scripts | Python     | 2k
# 201  | butteraugli                    | C++        | 2k
# 202  | spatial-media                  | Python     | 2k
# 203  | rekall                         | Python     | 2k
# 204  | marl                           | C++        | 2k
# 205  | google-authenticator-libpam    | C          | 1.9k
# 206  | rune                           | C          | 1.9k
# 207  | sling                          | C++        | 1.9k
# 208  | tunix                          | Python     | 1.9k
# 209  | nerfies                        | Python     | 1.9k
# 210  | security-research-pocs         | C++        | 1.9k
# 211  | fruit                          | C++        | 1.9k
# 212  | argh                           | Rust       | 1.9k
# 213  | android-emulator-m1-preview    | Unknown    | 1.9k
# 214  | TensorNetwork                  | Python     | 1.9k
# 215  | python-adb                     | Python     | 1.8k
# 216  | closure-compiler-js            | JavaScript | 1.8k
# 217  | compare_gan                    | Python     | 1.8k
# 218  | protobuf-gradle-plugin         | Groovy     | 1.8k
# 219  | gemmlowp                       | C++        | 1.8k
# 220  | stenographer                   | Go         | 1.8k
# 221  | CausalImpact                   | R          | 1.8k
# 222  | go-jsonnet                     | Go         | 1.8k
# 223  | eslint-config-google           | JavaScript | 1.8k
# 224  | nomulus                        | Java       | 1.8k
# 225  | periph                         | Go         | 1.7k
# 226  | zoekt                          | Unknown    | 1.7k
# 227  | sandboxed-api                  | C++        | 1.7k
# 228  | woff2                          | C++        | 1.7k
# 229  | novm                           | Go         | 1.7k
# 230  | aiyprojects-raspbian           | Python     | 1.7k
# 231  | google-authenticator-android   | Java       | 1.7k
# 232  | UIforETW                       | C++        | 1.6k
# 233  | yamlfmt                        | Go         | 1.6k
# 234  | pyringe                        | Python     | 1.6k
# 235  | vizier                         | Python     | 1.6k
# 236  | json_serializable.dart         | Dart       | 1.6k
# 237  | highwayhash                    | C++        | 1.6k
# 238  | uis-rnn                        | Python     | 1.6k
# 239  | keytransparency                | Go         | 1.6k
# 240  | log4jscanner                   | Go         | 1.6k
# 241  | uncertainty-baselines          | Python     | 1.6k
# 242  | budoux                         | Python     | 1.5k
# 243  | atheris                        | Python     | 1.5k
# 244  | gofuzz                         | Go         | 1.5k
# 245  | go-safeweb                     | Go         | 1.5k
# 246  | live-transcribe-speech-engine  | Java       | 1.5k
# 247  | flogger                        | Java       | 1.5k
# 248  | tensorstore                    | C++        | 1.5k
# 249  | fuzzer-test-suite              | C          | 1.5k
# 250  | flutter.widgets                | Dart       | 1.4k
# 251  | jsonapi                        | Go         | 1.4k
# 252  | ion                            | C++        | 1.4k
# 253  | haskell-trainings              | Haskell    | 1.4k
# 254  | firing-range                   | Java       | 1.4k
# 255  | cloudprober                    | Go         | 1.4k
# 256  | crfs                           | Go         | 1.4k
# 257  | mathfu                         | C++        | 1.4k
# 258  | xls                            | C++        | 1.4k
# 259  | conscrypt                      | Java       | 1.4k
# 260  | pinject                        | Python     | 1.3k
# 261  | j2cl                           | Java       | 1.3k
# 262  | site-kit-wp                    | JavaScript | 1.3k
# 263  | sg2im                          | Python     | 1.3k
# 264  | monster-mash                   | C++        | 1.3k
# 265  | oss-fuzz-gen                   | Python     | 1.3k
# 266  | style-aligned                  | Python     | 1.3k
# 267  | typograms                      | JavaScript | 1.3k
# 268  | visualblocks                   | TypeScript | 1.3k
# 269  | skicka                         | Go         | 1.3k
# 270  | brain-tokyo-workshop           | Jupyter Notebook | 1.3k
# 271  | schism                         | Scheme     | 1.3k
# 272  | coding-competitions-archive    | HTML       | 1.3k
# 273  | nftables                       | Go         | 1.3k
# 274  | codeworld                      | Haskell    | 1.3k
# 275  | secrets-gradle-plugin          | Kotlin     | 1.3k
# 276  | glazier                        | Python     | 1.2k
# 277  | re2j                           | Java       | 1.2k
# 278  | nsync                          | C          | 1.2k
# 279  | modernstorage                  | Kotlin     | 1.2k
# 280  | neuroglancer                   | TypeScript | 1.2k
# 281  | prettytensor                   | Python     | 1.2k
# 282  | swissgl                        | JavaScript | 1.2k
# 283  | cityhash                       | Shell      | 1.2k
# 284  | textfsm                        | Python     | 1.2k
# 285  | lullaby                        | C++        | 1.2k
# 286  | google-toolbox-for-mac         | Objective-C | 1.2k
# 287  | meridian                       | Python     | 1.2k
# 288  | skylark                        | Go         | 1.2k
# 289  | makani                         | C++        | 1.2k
# 290  | budou                          | Python     | 1.2k
# 291  | proto-quic                     | Unknown    | 1.2k
# 292  | double-conversion              | C++        | 1.2k
# 293  | active-learning                | Python     | 1.2k
# 294  | fuzzbench                      | Python     | 1.2k
# 295  | binexport                      | C++        | 1.2k
# 296  | intermock                      | TypeScript | 1.2k
# 297  | wwwbasic                       | JavaScript | 1.1k
# 298  | vim-codefmt                    | Vim Script | 1.1k
# 299  | ssl_logger                     | Python     | 1.1k
# 300  | schema-dts                     | TypeScript | 1.1k
# 301  | adb-sync                       | Python     | 1.1k
# 302  | keyczar                        | Unknown    | 1.1k
# 303  | cmockery                       | Shell      | 1.1k
# 304  | crosvm                         | Rust       | 1.1k
# 305  | jsaction                       | JavaScript | 1.1k
# 306  | mundane                        | Rust       | 1.1k
# 307  | capslock                       | Go         | 1.1k
# 308  | certificate-transparency-go    | Go         | 1.1k
# 309  | quiver-dart                    | Dart       | 1.1k
# 310  | agi                            | Go         | 1k
# 311  | lightweight_mmm                | Python     | 1k
# 312  | cluster-data                   | TeX        | 1k
# 313  | jaxopt                         | Python     | 1k
# 314  | ml_collections                 | Python     | 998
# 315  | dreambooth                     | Unknown    | 998
# 316  | kati                           | Rust       | 994
# 317  | it-cert-automation-practice    | Python     | 986
# 318  | badwolf                        | Go         | 984
# 319  | rowhammer-test                 | C++        | 984
# 320  | longfellow-zk                  | C++        | 983
# 321  | fscrypt                        | Go         | 983
# 322  | clif                           | C++        | 981
# 323  | asylo                          | C++        | 980
# 324  | adk-docs                       | HTML       | 976
# 325  | adk-java                       | Java       | 971
# 326  | go-licenses                    | Go         | 961
# 327  | packetdrill                    | C          | 950
# 328  | android-arscblamer             | Java       | 946
# 329  | hypernerf                      | Python     | 943
# 330  | tsunami-security-scanner-plugins | Java       | 942
# 331  | swift-benchmark                | Swift      | 936
# 332  | mipnerf                        | Python     | 933
# 333  | fuzztest                       | C++        | 925
# 334  | evojax                         | Jupyter Notebook | 925
# 335  | crubit                         | C++        | 924
# 336  | namebench                      | Go         | 923
# 337  | gousb                          | Go         | 919
# 338  | xsecurelock                    | C          | 914
# 339  | mr4c                           | Java       | 907
# 340  | fhir                           | C++        | 905
# 341  | jax-cfd                        | Jupyter Notebook | 894
# 342  | logger                         | Go         | 889
# 343  | nearby                         | C++        | 888
# 344  | built_value.dart               | Dart       | 883
# 345  | certificate-transparency       | C++        | 882
# 346  | inception                      | Unknown    | 878
# 347  | langfun                        | Python     | 875
# 348  | rappor                         | R          | 869
# 349  | inject.dart                    | Dart       | 867
# 350  | cld3                           | C++        | 856
# 351  | vsaq                           | JavaScript | 856
# 352  | ringdroid                      | Java       | 854
# 353  | transit                        | Unknown    | 852
# 354  | hdrnet                         | Python     | 851
# 355  | addlicense                     | Go         | 850
# 356  | android-emulator-hypervisor-driver | C          | 842
# 357  | capirca                        | Python     | 839
# 358  | visqol                         | C++        | 836
# 359  | swift                          | Unknown    | 836
# 360  | private-join-and-compute       | C++        | 834
# 361  | private-join-and-compute       | C++        | 834
# 362  | google-api-objectivec-client-for-rest | Objective-C | 830
# 363  | generative-ai-go               | Go         | 830
# 364  | macops                         | Python     | 827
# 365  | pygtrie                        | Python     | 824
# 366  | gcm                            | Java       | 823
# 367  | emoji-scavenger-hunt           | TypeScript | 819
# 368  | caliper                        | Java       | 819
# 369  | dynibar                        | Python     | 813
# 370  | flutter-provide                | Dart       | 804
# 371  | gps-measurement-tools          | Java       | 803
# 372  | quiche                         | C++        | 801
# 373  | nucleus                        | C++        | 797
# 374  | paranoid_crypto                | Python     | 796
# 375  | learned_optimization           | Python     | 788
# 376  | android-gradle-dsl             | HTML       | 785
# 377  | subcommands                    | Go         | 781
# 378  | dawn                           | C++        | 780
# 379  | turbinia                       | Python     | 777
# 380  | objax                          | Python     | 775
# 381  | cloud-print-connector          | Go         | 765
# 382  | goexpect                       | Go         | 758
# 383  | FluidNet                       | Lua        | 755
# 384  | brunsli                        | C++        | 745
# 385  | earthengine-community          | Jupyter Notebook | 744
# 386  | google-api-java-client-samples | Java       | 741
# 387  | ml-compiler-opt                | Python     | 737
# 388  | eng-edu                        | Jupyter Notebook | 734
# 389  | kctf                           | Go         | 731
# 390  | tachometer                     | TypeScript | 726
# 391  | simhospital                    | Go         | 717
# 392  | mobly                          | Python     | 716
# 393  | rerast                         | Rust       | 715
# 394  | compile-testing                | Java       | 715
# 395  | graph-mining                   | C++        | 712
# 396  | oauth2l                        | Go         | 709
# 397  | temporian                      | Python     | 703
# 398  | edward2                        | Jupyter Notebook | 702
# 399  | pyglove                        | Python     | 699
# 400  | clspv                          | LLVM       | 693
# 401  | transitfeed                    | Python     | 690
# 402  | startup-os                     | Java       | 687
# 403  | iconvg                         | C          | 682
# 404  | blockly-android                | Java       | 680
# 405  | ioweb2015                      | JavaScript | 680
# 406  | voice-builder                  | JavaScript | 679
# 407  | adk-web                        | TypeScript | 677
# 408  | closure-templates              | Java       | 671
# 409  | oss-rebuild                    | Go         | 670
# 410  | renameio                       | Go         | 667
# 411  | GoogleSignIn-iOS               | Objective-C | 667
# 412  | samba-documents-provider       | Java       | 666
# 413  | ml-metadata                    | C++        | 666
# 414  | horologist                     | Kotlin     | 658
# 415  | flatui                         | C++        | 651
# 416  | farmhash                       | C++        | 644
# 417  | santa-tracker-web              | JavaScript | 644
# 418  | svcca                          | Jupyter Notebook | 639
# 419  | libprotobuf-mutator            | C++        | 635
# 420  | cctz                           | C++        | 631
# 421  | playground-elements            | TypeScript | 627
# 422  | patents-public-data            | Jupyter Notebook | 627
# 423  | swift-jupyter                  | Python     | 623
# 424  | yggdrasil-decision-forests     | C++        | 622
# 425  | webauthndemo                   | TypeScript | 621
# 426  | go-tpm                         | Go         | 618
# 427  | project-gameface               | Java       | 617
# 428  | sqlcommenter                   | PHP        | 616
# 429  | openhtf                        | Python     | 614
# 430  | github-issue-mover             | Dart       | 612
# 431  | heir                           | C++        | 610
# 432  | libaddressinput                | C++        | 606
# 433  | gitiles                        | Java       | 603
# 434  | grain                          | Python     | 603
# 435  | graphicsfuzz                   | Java       | 595
# 436  | easypki                        | Go         | 593
# 437  | vim-maktaba                    | Vim Script | 589
# 438  | palette.js                     | JavaScript | 589
# 439  | seqio                          | Python     | 589
# 440  | u2f-ref-code                   | JavaScript | 588
# 441  | season-of-docs                 | Unknown    | 579
# 442  | s2-geometry-library-java       | Java       | 578
# 443  | qkeras                         | Python     | 578
# 444  | vulncode-db                    | Python     | 577
# 445  | libnop                         | C++        | 576
# 446  | autofdo                        | C++        | 576
# 447  | usd_from_gltf                  | C++        | 572
# 448  | android-fhir                   | Kotlin     | 571
# 449  | android-cuttlefish             | C++        | 571
# 450  | ktsan                          | Unknown    | 569
# 451  | subpar                         | Python     | 568
# 452  | module-server                  | JavaScript | 565
# 453  | protobuf.dart                  | Dart       | 558
# 454  | vpn-libraries                  | C++        | 554
# 455  | spherical-harmonics            | C++        | 552
# 456  | recki-ct                       | PHP        | 551
# 457  | search-samples                 | Java       | 549
# 458  | docker-explorer                | Python     | 548
# 459  | ukip                           | Python     | 546
# 460  | slo-generator                  | Python     | 546
# 461  | AEUX                           | JavaScript | 541
# 462  | paxml                          | Python     | 540
# 463  | tacotron                       | HTML       | 540
# 464  | personfinder                   | Python     | 540
# 465  | archive-patcher                | Java       | 540
# 466  | osv-scalibr                    | Go         | 538
# 467  | docsy-example                  | HTML       | 537
# 468  | CFU-Playground                 | Verilog    | 536
# 469  | google.github.io               | HTML       | 534
# 470  | private-compute-services       | Java       | 532
# 471  | schedviz                       | Go         | 530
# 472  | coding-with-chrome             | JavaScript | 530
# 473  | exposure-notifications-android | Java       | 529
# 474  | gke-policy-automation          | Go         | 525
# 475  | break-a-scene                  | Python     | 525
# 476  | cronet-transport-for-okhttp    | Java       | 523
# 477  | triage-party                   | Go         | 521
# 478  | ioweb2016                      | HTML       | 519
# 479  | mechahamster                   | C#         | 509
# 480  | clusterfuzzlite                | Unknown    | 509
# 481  | rustcxx                        | Rust       | 509
# 482  | mechahamster                   | C#         | 509
# 483  | transmat                       | TypeScript | 507
# 484  | react-schemaorg                | TypeScript | 506
# 485  | safeside                       | C++        | 505
# 486  | play-services-plugins          | Java       | 503
# 487  | dart-neats                     | Dart       | 503
# 488  | caliban                        | Python     | 500
# 489  | capillary                      | Java       | 500
# 490  | Accessibility-Test-Framework-for-Android | Java       | 499
# 491  | pybadges                       | Python     | 498
# 492  | crc32c                         | C++        | 498
# 493  | proto-lens                     | Haskell    | 497
# 494  | tf_mesh_renderer               | Python     | 497
# 495  | mannequinchallenge             | Python     | 496
# 496  | trace-viewer                   | Unknown    | 491
# 497  | cloud-forensics-utils          | Python     | 489
# 498  | safebrowsing                   | Go         | 488
# 499  | talkback                       | Java       | 488
# 500  | allocation-instrumenter        | Java       | 487
# 501  | licensecheck                   | Go         | 483
# 502  | cargo-raze                     | Rust       | 481
# 503  | adiantum                       | C          | 477
# 504  | gsocguides                     | CSS        | 475
# 505  | knusperli                      | C++        | 469
# 506  | kernel-sanitizers              | Python     | 468
# 507  | buzzer                         | Go         | 468
# 508  | h2e_technical_documentation    | Unknown    | 467
# 509  | play-unity-plugins             | C#         | 465
# 510  | riegeli                        | C++        | 465
# 511  | play-unity-plugins             | C#         | 465
# 512  | gmail-oauth2-tools             | Python     | 465
# 513  | shenzhen-go                    | JavaScript | 464
# 514  | walt                           | Java       | 462
# 515  | orbax                          | Python     | 455
# 516  | gtest-parallel                 | Python     | 454
# 517  | upvote_py2                     | Python     | 452
# 518  | snappy-start                   | C          | 450
# 519  | gdata-python-client            | HTML       | 450
# 520  | nerfactor                      | Python     | 449
# 521  | latency-benchmark              | C          | 446
# 522  | mug                            | Java       | 444
# 523  | gf180mcu-pdk                   | Makefile   | 442
# 524  | magritte                       | C++        | 441
# 525  | mediapy                        | Jupyter Notebook | 440
# 526  | data-layer-helper              | JavaScript | 440
# 527  | pienoon                        | C++        | 438
# 528  | speaker-id                     | Python     | 436
# 529  | music-synthesizer-for-android  | Jupyter Notebook | 434
# 530  | googlemock                     | Unknown    | 433
# 531  | go-replayers                   | Go         | 432
# 532  | clojure-turtle                 | Clojure    | 428
# 533  | bumble                         | Python     | 426
# 534  | digitalbuildings               | Python     | 425
# 535  | MOE                            | Java       | 422
# 536  | huproxy                        | Go         | 422
# 537  | go-microservice-helpers        | Go         | 418
# 538  | kmsan                          | C          | 417
# 539  | TestParameterInjector          | Java       | 415
# 540  | silifuzz                       | C++        | 413
# 541  | silifuzz                       | C++        | 413
# 542  | radioreceiver                  | JavaScript | 411
# 543  | uribeacon                      | Unknown    | 410
# 544  | blockly-ios                    | Swift      | 409
# 545  | ads-privacy                    | Unknown    | 408
# 546  | REAPER                         | C++        | 408
# 547  | googleapis.dart                | Dart       | 408
# 548  | stereo-magnification           | Python     | 406
# 549  | go-attestation                 | Go         | 406
# 550  | mcp-security                   | Python     | 404
# 551  | RB-Modulation                  | Jupyter Notebook | 402
# 552  | vimscript-language-server      | Rust       | 401
# 553  | gitprotocolio                  | Go         | 400
# 554  | kf                             | Go         | 400
# 555  | googletest-rust                | Rust       | 393
# 556  | aside                          | TypeScript | 392
# 557  | beacon-platform                | Unknown    | 391
# 558  | desugar_jdk_libs               | Java       | 389
# 559  | cameratrapai                   | Python     | 387
# 560  | etc2comp                       | C++        | 387
# 561  | language-resources             | C++        | 386
# 562  | hiba                           | C          | 384
# 563  | reflectable.dart               | Dart       | 382
# 564  | acme                           | Go         | 382
# 565  | aistplusplus_api               | Python     | 380
# 566  | mysql-ripple                   | C++        | 377
# 567  | syzygy                         | C++        | 377
# 568  | flutter_flux                   | Dart       | 376
# 569  | csp-evaluator                  | TypeScript | 374
# 570  | safehtml                       | Go         | 373
# 571  | vim-searchindex                | Vim Script | 369
# 572  | lifetime_value                 | Jupyter Notebook | 365
# 573  | fiddle                         | Python     | 364
# 574  | autobound                      | Python     | 363
# 575  | flaxformer                     | Python     | 363
# 576  | slang-gaussian-rasterization   | Python     | 362
# 577  | tie                            | JavaScript | 361
# 578  | pasta                          | Python     | 359
# 579  | CommonLoopUtils                | Jupyter Notebook | 358
# 580  | next-prediction                | Python     | 356
# 581  | deps.dev                       | Go         | 355
# 582  | revisiting-self-supervised     | Python     | 353
# 583  | blueprint                      | Go         | 352
# 584  | functional-objc                | Objective-C | 350
# 585  | making_with_ml                 | Jupyter Notebook | 348
# 586  | import-mailbox-to-gmail        | Python     | 346
# 587  | cpp-netlib                     | C++        | 344
# 588  | active-qa                      | Python     | 343
# 589  | vanir                          | Python     | 342
# 590  | minijail                       | C          | 342
# 591  | vector_math.dart               | Dart       | 341
# 592  | gcp_scanner                    | Python     | 341
# 593  | kafel                          | C          | 340
# 594  | closure-compiler-npm           | JavaScript | 339
# 595  | licenseclassifier              | Go         | 339
# 596  | ffn                            | Python     | 338
# 597  | pawn                           | C++        | 337
# 598  | randen                         | C++        | 337
# 599  | aqt                            | Python     | 337
# 600  | godepq                         | Go         | 335
# 601  | fplutil                        | Python     | 335
# 602  | godepq                         | Go         | 335
# 603  | paco                           | Objective-C | 332
# 604  | node-gles                      | C++        | 331
# 605  | esh                            | C          | 331
# 606  | perf_data_converter            | C++        | 331
# 607  | google-api-ruby-client-samples | Unknown    | 330
# 608  | dotprompt                      | Python     | 330
# 609  | node-h2-auto-push              | TypeScript | 328
# 610  | gwpsan                         | C++        | 327
# 611  | diffseg                        | Jupyter Notebook | 327
# 612  | smali                          | Java       | 325
# 613  | pepper.js                      | JavaScript | 324
# 614  | mentornet                      | Python     | 324
# 615  | password-alert                 | JavaScript | 322
# 616  | Xee                            | Python     | 321
# 617  | ldif                           | Python     | 320
# 618  | neper                          | C          | 318
# 619  | keep-sorted                    | Go         | 318
# 620  | VoltAir                        | C++        | 317
# 621  | ruy                            | C++        | 316
# 622  | ml-fairness-gym                | Python     | 316
# 623  | closure-stylesheets            | Java       | 315
# 624  | gnostic-grpc                   | Go         | 314
# 625  | fchan-go                       | Go         | 311
# 626  | thread-weaver                  | Java       | 309
# 627  | multibox                       | Unknown    | 307
# 628  | grr-doc                        | Shell      | 307
# 629  | alioth                         | Rust       | 307
# 630  | tirg                           | Python     | 304
# 631  | vimdoc                         | Python     | 304
# 632  | google-api-objectivec-client   | Unknown    | 303
# 633  | jni-bind                       | C++        | 303
# 634  | google-api-cpp-client          | C++        | 303
# 635  | portrait-shadow-manipulation   | Jupyter Notebook | 302
# 636  | dfiq                           | Python     | 294
# 637  | neural-logic-machines          | Python     | 293
# 638  | zooshi                         | C++        | 291
# 639  | wicked-good-xpath              | JavaScript | 289
# 640  | pprof-nodejs                   | JavaScript | 288
# 641  | google-visualization-issues    | Unknown    | 286
# 642  | hilbert                        | Go         | 286
# 643  | vxsig                          | C++        | 284
# 644  | built_collection.dart          | Dart       | 283
# 645  | kratu                          | JavaScript | 283
# 646  | gnxi                           | Python     | 282
# 647  | shaderc-rs                     | Rust       | 282
# 648  | EXEgesis                       | C++        | 281
# 649  | pyink                          | Python     | 280
# 650  | sagetv                         | Java       | 280
# 651  | learn_unsafe_rust              | Unknown    | 279
# 652  | cauliflowervest                | Python     | 278
# 653  | osqp-cpp                       | C++        | 277
# 654  | jpegli                         | C++        | 277
# 655  | neural-light-transport         | Python     | 277
# 656  | patchfield                     | Java       | 277
# 657  | cpp-from-the-sky-down          | HTML       | 276
# 658  | deepsomatic                    | Unknown    | 276
# 659  | psp                            | C          | 276
# 660  | jetpack-camera-app             | Kotlin     | 276
# 661  | vroom                          | Python     | 274
# 662  | chrome-ssh-agent               | Go         | 274
# 663  | ground-android                 | Kotlin     | 273
# 664  | go-tpm-tools                   | C          | 273
# 665  | shipshape                      | Go         | 270
# 666  | flutter-mediapipe              | Dart       | 270
# 667  | dynamic-video-depth            | Python     | 270
# 668  | casa-android                   | Kotlin     | 270
# 669  | vim-colorscheme-primary        | Vim Script | 268
# 670  | fedjax                         | Python     | 266
# 671  | grinder.dart                   | Dart       | 266
# 672  | google-input-tools             | JavaScript | 265
# 673  | gtm-session-fetcher            | Objective-C | 265
# 674  | mail-importer                  | Java       | 264
# 675  | libultrahdr                    | C++        | 264
# 676  | in-silico-labeling             | Python     | 262
# 677  | inverting-proxy                | Go         | 262
# 678  | uVkCompute                     | C++        | 257
# 679  | rust-crate-audits              | Unknown    | 255
# 680  | myanmar-tools                  | Java       | 255
# 681  | iosched-ios                    | Swift      | 254
# 682  | go-tika                        | Go         | 253
# 683  | centipede                      | Unknown    | 252
# 684  | slowjam                        | HTML       | 252
# 685  | deepconsensus                  | Python     | 252
# 686  | hat-backup                     | Rust       | 252
# 687  | path-auditor                   | C++        | 252
# 688  | corgi                          | C++        | 251
# 689  | vulkan-cpp-library             | C++        | 250
# 690  | ot-crdt-papers                 | JavaScript | 249
# 691  | der-ascii                      | Go         | 248
# 692  | burst-denoising                | Python     | 247
# 693  | flutter-stager                 | Dart       | 246
# 694  | etils                          | Python     | 244
# 695  | android-riscv64                | Unknown    | 242
# 696  | weather-tools                  | Python     | 241
# 697  | compact_enc_det                | C          | 239
# 698  | exposure-notifications-verification-server | Go         | 239
# 699  | cocoapods-size                 | Python     | 237
# 700  | ghost-userspace                | C          | 236
# 701  | lmeval                         | Python     | 235
# 702  | new-project                    | Unknown    | 234
# 703  | GTXiLib                        | Objective-C | 233
# 704  | prefab                         | Kotlin     | 229
# 705  | trajax                         | Python     | 228
# 706  | ci_edit                        | Python     | 228
# 707  | ground-platform                | TypeScript | 227
# 708  | ghost-kernel                   | C          | 227
# 709  | cel-java                       | Java       | 227
# 710  | restor                         | Objective-C | 226
# 711  | liblc3                         | C          | 225
# 712  | lipsync                        | JavaScript | 225
# 713  | rust-shell                     | Rust       | 225
# 714  | fuse-archive                   | C++        | 223
# 715  | imageinwords                   | JavaScript | 223
# 716  | git-appraise-web               | HTML       | 223
# 717  | explaining-in-style            | Jupyter Notebook | 223
# 718  | mount-zip                      | C++        | 221
# 719  | ffcc                           | MATLAB     | 217
# 720  | goterm                         | Go         | 216
# 721  | tcp_killer                     | Python     | 214
# 722  | extra-keyboards-for-chrome-os  | JavaScript | 214
# 723  | amber                          | C++        | 214
# 724  | android-key-attestation        | Java       | 213
# 725  | containerregistry              | Python     | 212
# 726  | sparrowhawk                    | Shell      | 212
# 727  | mysql-tools                    | Python     | 212
# 728  | corpuscrawler                  | Python     | 211
# 729  | transperf                      | Python     | 210
# 730  | region-flags                   | HTML       | 210
# 731  | capsicum-linux                 | C          | 210
# 732  | neural_rerendering_in_the_wild | Python     | 208
# 733  | supersonic                     | C++        | 207
# 734  | open-vcdiff                    | C++        | 205
# 735  | cel-cpp                        | C++        | 205
# 736  | e3d_lstm                       | Python     | 205
# 737  | fhir-data-pipes                | Jupyter Notebook | 204
# 738  | bazel-to-cmake                 | Python     | 204
# 739  | tree-math                      | Python     | 203
# 740  | pack                           | Rust       | 203
# 741  | motive                         | C++        | 202
# 742  | opendocs                       | Unknown    | 199
# 743  | minja                          | C++        | 198
# 744  | fplbase                        | C++        | 198
# 745  | ipaddr-py                      | Python     | 195
# 746  | devlibrary                     | Vue        | 194
# 747  | go-flow-levee                  | Go         | 194
# 748  | mdbook-i18n-helpers            | Rust       | 194
# 749  | tuple.dart                     | Dart       | 194
# 750  | starlark-rust                  | Unknown    | 193
# 751  | CodeCity                       | JavaScript | 193
# 752  | canvas-5-polyfill              | JavaScript | 192
# 753  | libcxx                         | C++        | 192
# 754  | praxis                         | Python     | 190
# 755  | shlex                          | Go         | 190
# 756  | vpn-reverse-tether             | C          | 190
# 757  | gonids                         | Go         | 189
# 758  | marmot                         | Go         | 189
# 759  | python-gflags                  | Python     | 188
# 760  | integers                       | C++        | 188
# 761  | sre_yield                      | Python     | 187
# 762  | php-crc32                      | PHP        | 186
# 763  | gdata-objectivec-client        | Objective-C | 186
# 764  | todo-tracks                    | Go         | 185
# 765  | glance-experimental-tools      | Kotlin     | 185
# 766  | instant-hangouts               | JavaScript | 184
# 767  | dnsmasq_exporter               | Go         | 183
# 768  | service-worker-detector        | JavaScript | 183
# 769  | cppdap                         | C++        | 182
# 770  | pcbdl                          | Python     | 182
# 771  | js-green-licenses              | TypeScript | 181
# 772  | goblet                         | Go         | 181
# 773  | go-cmdtest                     | Go         | 180
# 774  | tensorflow-recorder            | Python     | 180
# 775  | virtual-authenticators-tab     | JavaScript | 179
# 776  | vae-seq                        | Python     | 177
# 777  | TrustScore                     | Jupyter Notebook | 177
# 778  | importlab                      | Python     | 177
# 779  | eDistantObject                 | Objective-C | 176
# 780  | retiming                       | Python     | 176
# 781  | eDistantObject                 | Objective-C | 176
# 782  | scaaml                         | Python     | 175
# 783  | inspectorspacetime             | JavaScript | 175
# 784  | encrypted-bigquery-client      | Python     | 175
# 785  | evolve-forms                   | Apex       | 175
# 786  | minimalloc                     | C++        | 175
# 787  | gcnn-survey-paper              | Python     | 174
# 788  | python-subprocess32            | Python     | 173
# 789  | trillian-examples              | Go         | 173
# 790  | starthinker                    | Python     | 173
# 791  | node-sec-roadmap               | JavaScript | 173
# 792  | zimtohrli                      | Jupyter Notebook | 173
# 793  | osdfir-infrastructure          | Smarty     | 172
# 794  | lasr                           | Python     | 172
# 795  | kasane                         | Python     | 172
# 796  | detangle                       | JavaScript | 171
# 797  | ctfscoreboard                  | Python     | 171
# 798  | dimsum                         | C++        | 171
# 799  | llvm-bazel                     | Starlark   | 170
# 800  | loaner                         | Python     | 170
# 801  | turing-doodle                  | JavaScript | 170
# 802  | cluster-scheduler-simulator    | Scala      | 170
# 803  | classp                         | Bison      | 169
# 804  | data-driven-discretization-1d  | Jupyter Notebook | 168
# 805  | crumsort-rs                    | Rust       | 168
# 806  | moveit                         | Rust       | 168
# 807  | elemental2                     | Java       | 167
# 808  | automotive-design-compose      | Rust       | 167
# 809  | googlesre                      | TypeScript | 167
# 810  | render-timing-for-unity        | C++        | 167
# 811  | oss-fuzz-vulns                 | Python     | 166
# 812  | LiquidFunPaint                 | Java       | 166
# 813  | googletv-android-samples       | Java       | 165
# 814  | uniflow-polymer                | HTML       | 165
# 815  | fancy-regex                    | Rust       | 165
# 816  | mono_repo.dart                 | Dart       | 165
# 817  | lecam-gan                      | Jupyter Notebook | 165
# 818  | travel-impact-model            | Unknown    | 164
# 819  | dart-basics                    | Dart       | 164
# 820  | zetasketch                     | Java       | 163
# 821  | security-crawl-maze            | HTML       | 163
# 822  | apis-client-generator          | Python     | 162
# 823  | postcss-rename                 | TypeScript | 162
# 824  | redgrep                        | C++        | 162
# 825  | x-amber                        | C          | 162
# 826  | vim-jsonnet                    | Vim Script | 161
# 827  | chicago-brick                  | TypeScript | 161
# 828  | xr-objects                     | C#         | 161
# 829  | knative-gcp                    | Go         | 161
# 830  | gwtmockito                     | Java       | 160
# 831  | pytruth                        | Python     | 159
# ...
# 2525 | course-builder                 | Unknown    | 5
# 2526 | favcolor-findidp               | Unknown    | 5
# 2527 | jenkins-flaky-test-report      | Unknown    | 5
# 2528 | coursebuilder-learning-analytics | Unknown    | 5
# 2529 | go-glicko2                     | Unknown    | 5
# 2530 | gin                            | Unknown    | 5
# 2531 | go-shlex                       | Unknown    | 5
# 2532 | citizen-x                      | Unknown    | 5
# 2533 | network-visualizer-x           | Unknown    | 5
# 2534 | auto-factory                   | Unknown    | 5
# 2535 | auto-service                   | Unknown    | 5
# 2536 | auto-common                    | Unknown    | 5
# 2537 | dev-on-chromeos-che            | Unknown    | 5
# 2538 | standard-payments              | Unknown    | 5
# 2539 | cloud-network-reachability     | Unknown    | 5
# 2540 | skywater-pdk-libs-sky90fd_fd_sc | Unknown    | 5
# 2541 | asml                           | Unknown    | 5
# 2542 | task-oriented-queries          | Unknown    | 5
# 2543 | gfbuild-amber                  | Shell      | 5
# 2544 | cornerstoneTools               | JavaScript | 5
# 2545 | cornerstoneWebImageLoader      | JavaScript | 5
# 2546 | cornerstoneWADOImageLoader     | JavaScript | 5
# 2547 | sa360-bulk-editor              | JavaScript | 5
# 2548 | vapso                          | JavaScript | 5
# 2549 | trueview-sdf-generator         | JavaScript | 5
# 2550 | cm-user-tool                   | JavaScript | 5
# 2551 | wikiloop-wikidata-game         | JavaScript | 5
# 2552 | sa360-bidbyweather             | JavaScript | 5
# 2553 | dv-3po                         | JavaScript | 5
# 2554 | recog                          | JavaScript | 5
# 2555 | talos-dv360                    | JavaScript | 5
# 2556 | budget-protector               | JavaScript | 5
# 2557 | ad_language_monitor            | JavaScript | 5
# 2558 | drive-file-search-fix          | JavaScript | 5
# 2559 | swift-llbuild                  | C++        | 5
# 2560 | protodatastore-cpp             | C++        | 5
# 2561 | http_pattern_matcher           | C++        | 5
# 2562 | gsrsup                         | C++        | 5
# 2563 | cairn                          | C++        | 5
# 2564 | foteli                         | C++        | 5
# 2565 | imt                            | C++        | 5
# 2566 | io-captions-gadget             | Python     | 5
# 2567 | repose                         | Python     | 5
# 2568 | rescue-tools-reiserfs          | Python     | 5
# 2569 | structured_labels              | Python     | 5
# 2570 | blockbuster                    | Python     | 5
# 2571 | deluca-lung                    | Python     | 5
# 2572 | adh-deployment-manager         | Python     | 5
# 2573 | Vulkan-Errata                  | Python     | 5
# 2574 | html-to-jsonld-converter       | Python     | 5
# 2575 | mobly-android-screen-recorder  | Python     | 5
# 2576 | mobly-bluetooth-ref-validation | Python     | 5
# 2577 | bt-navi-tests                  | Python     | 5
# 2578 | swift-cmark                    | C          | 5
# 2579 | swift-compiler-rt              | C          | 5
# 2580 | swift-corelibs-foundation      | C          | 5
# 2581 | swift-corelibs-libdispatch     | C          | 5
# 2582 | eiffel                         | C          | 5
# 2583 | pods-helper                    | Objective-C | 5
# 2584 | ytstatistics-demo              | Java       | 5
# 2585 | wear-displaylock               | Java       | 5
# 2586 | opentest4j                     | Java       | 5
# 2587 | sha1dc-jni                     | Java       | 5
# 2588 | java-run                       | Java       | 5
# 2589 | app-metadata-encoder           | Java       | 5
# 2590 | unity-anr-plugin               | Java       | 5
# 2591 | crumbles                       | Java       | 5
# 2592 | fast-optimized-community-significance | R          | 5
# 2593 | skywater-pdk-libs-sky130_fd_sc_hs | Verilog    | 5
# 2594 | skywater-pdk-libs-sky130_fd_sc_ms | Verilog    | 5
# 2595 | skywater-pdk-libs-sky130_fd_sc_ls | Verilog    | 5
# 2596 | grr_go_api_client              | Go         | 5
# 2597 | grr_go_client                  | Go         | 5
# 2598 | gcb-tools                      | Go         | 5
# 2599 | ORFConverter                   | C#         | 5
# 2600 | receipts-to-riches-part1       | C#         | 5
# 2601 | decoder-benchmarks-for-rust    | Rust       | 5
# 2602 | secure-aggregation             | Rust       | 5
# 2603 | librato.dart                   | Dart       | 5
# 2604 | conversion-audit               | TypeScript | 5
# 2605 | travel-impact-model-website    | TypeScript | 5
# 2606 | vscode-vnc                     | TypeScript | 5
# 2607 | swift-corelibs-xctest          | Swift      | 5
# 2608 | dropzone-polyfill              | HTML       | 5
# 2609 | chive-prosody                  | HTML       | 5
# 2610 | controlled-noisy-web-labels    | HTML       | 5
# 2611 | deepmac                        | HTML       | 5
# 2612 | look-before-you-speak          | HTML       | 5
# 2613 | polynomial-practice            | HTML       | 5
# 2614 | gdal-autotest2                 | Unknown    | 4
# 2615 | photo-sphere                   | Unknown    | 4
# 2616 | deliberate                     | Unknown    | 4
# 2617 | older-mirrored-patches         | Unknown    | 4
# 2618 | gitwf                          | Unknown    | 4
# 2619 | sass_generator                 | Unknown    | 4
# 2620 | git-annex-external-gcs         | Unknown    | 4
# 2621 | river                          | Unknown    | 4
# 2622 | node-armor                     | Unknown    | 4
# 2623 | fleetspeak-doc                 | Unknown    | 4
# 2624 | HardwarePrototypingToolkit     | Unknown    | 4
# 2625 | x                              | Unknown    | 4
# 2626 | overcoming-conflicting-data    | Unknown    | 4
# 2627 | skywater-pdk-libs-sky90fd_osu_sc | Unknown    | 4
# 2628 | skywater-pdk-libs-sky90fd_fd_io | Unknown    | 4
# 2629 | partner-ads-experience         | Unknown    | 4
# 2630 | deshell                        | Unknown    | 4
# 2631 | saif-data                      | Unknown    | 4
# 2632 | myvibe                         | Unknown    | 4
# 2633 | param_runner                   | Shell      | 4
# 2634 | backup-dr-custom-roles         | Shell      | 4
# 2635 | premium-vs-standard-network-latency | Shell      | 4
# 2636 | node-nest                      | JavaScript | 4
# 2637 | gulp-google-closure-deps       | JavaScript | 4
# 2638 | CurbsidePickup                 | JavaScript | 4
# 2639 | outrigger                      | JavaScript | 4
# 2640 | custom-tab-groups              | JavaScript | 4
# 2641 | step197-2020                   | Java       | 4
# 2642 | peg-typed                      | Kotlin     | 4
# 2643 | outrigger                      | JavaScript | 4
# 2644 | x                              | Unknown    | 4
# 2645 | overcoming-conflicting-data    | Unknown    | 4
# 2646 | xscreensaver-dbus              | Haskell    | 4
# 2647 | skywater-pdk-libs-sky130_fd_sc_hvl | Verilog    | 4
# 2648 | custom-tab-groups              | JavaScript | 4
# 2649 | cpp-proto-builder              | C++        | 4
# 2650 | vscode-zxdb                    | TypeScript | 4
# 2651 | hs-dependent-literals          | Haskell    | 4
# 2652 | hs-ten                         | Haskell    | 4
# 2653 | nsc-tutorial                   | Jupyter Notebook | 4
# 2654 | trusted-worklet-server         | C++        | 4
# 2655 | android-cuttlefish-authentication | Python     | 4
# 2656 | phoneme-aligned-graphemes-in-tts | HTML       | 4
# 2657 | postcss-src                    | TypeScript | 4
# 2658 | exists-ref                     | Rust       | 4
# 2659 | sxg-validator                  | JavaScript | 4
# 2660 | nanopb-cpputest-comparators    | C++        | 4
# 2661 | draft-todo-chariton-dns-account-01 | Dockerfile | 4
# 2662 | backup-dr-custom-roles         | Shell      | 4
# 2663 | pmax_migration                 | Python     | 4
# 2664 | skywater-pdk-libs-sky90fd_osu_sc | Unknown    | 4
# 2665 | skywater-pdk-libs-sky90fd_fd_io | Unknown    | 4
# 2666 | rtb_creative_filtering_report  | TypeScript | 4
# 2667 | uafcs                          | Python     | 4
# 2668 | traceviz                       | TypeScript | 4
# 2669 | mpact-sim-codelabs             | C++        | 4
# 2670 | partner-ads-experience         | Unknown    | 4
# 2671 | page-alloc-bench               | Go         | 4
# 2672 | cc-device-plugin               | Go         | 4
# 2673 | exists-ref                     | Rust       | 4
# 2674 | ippusb                         | Rust       | 4
# 2675 | pts-bot                        | Rust       | 4
# 2676 | peg-typed                      | Kotlin     | 4
# 2677 | intellij-kotlin                | Kotlin     | 4
# 2678 | vscode-zxdb                    | TypeScript | 4
# 2679 | postcss-src                    | TypeScript | 4
# 2680 | rtb_creative_filtering_report  | TypeScript | 4
# 2681 | traceviz                       | TypeScript | 4
# 2682 | search-in-apps                 | Swift      | 4
# 2683 | speech_style_transfer          | HTML       | 4
# 2684 | phase-prediction               | HTML       | 4
# 2685 | StrawNet                       | HTML       | 4
# 2686 | phoneme-aligned-graphemes-in-tts | HTML       | 4
# 2687 | nsc-tutorial                   | Jupyter Notebook | 4
# 2688 | draft-todo-chariton-dns-account-01 | Dockerfile | 4
# 2689 | jsontoken-tmp                  | Unknown    | 3
# 2690 | reboot-somalia                 | Unknown    | 3
# 2691 | organ-donor-app                | Unknown    | 3
# 2692 | xpra-upstart                   | Unknown    | 3
# 2693 | physical-web-core              | Unknown    | 3
# 2694 | google-empty-test-module       | Unknown    | 3
# 2695 | opentest                       | Unknown    | 3
# 2696 | gfbuild-SPIRV-Cross            | Unknown    | 3
# 2697 | icing-search                   | Unknown    | 3
# 2698 | cloud-network-reachabilty      | Unknown    | 3
# 2699 | or-models                      | Unknown    | 3
# 2700 | sonic-p4rt                     | Unknown    | 3
# 2701 | fhir-ml                        | Unknown    | 3
# 2702 | devsite-template               | Unknown    | 3
# 2703 | fledge-key-value-server        | Unknown    | 3
# 2704 | closure-net                    | Unknown    | 3
# 2705 | skcms                          | Unknown    | 3
# 2706 | gfbuild-shadertrap             | Shell      | 3
# 2707 | profit-bidder                  | Shell      | 3
# 2708 | java-video-live-stream         | Shell      | 3
# 2709 | amot                           | Shell      | 3
# 2710 | videotts                       | JavaScript | 3
# 2711 | baby-alligator                 | JavaScript | 3
# 2712 | trusted-key-value-server       | C++        | 3
# 2713 | process-tree                   | C++        | 3
# 2714 | loudness_ebur128               | C++        | 3
# 2715 | image-supplemental-feed-creator | Python     | 3
# 2716 | distla_core                    | Python     | 3
# 2717 | parallel_accel                 | Python     | 3
# 2718 | memutil                        | Python     | 3
# 2719 | mint-line-follower             | Python     | 3
# 2720 | xssxss                         | C          | 3
# 2721 | testrunner-rosemary            | Java       | 3
# 2722 | step49-2020                    | Java       | 3
# 2723 | zero-touch-reseller-tool       | Java       | 3
# 2724 | floody                         | Java       | 3
# 2725 | snowflake-to-bq-data-transfer-tool | Java       | 3
# 2726 | hs-attenuation                 | Haskell    | 3
# 2727 | hs-batching                    | Haskell    | 3
# 2728 | hs-collate                     | Haskell    | 3
# 2729 | hs-fin-vec                     | Haskell    | 3
# 2730 | hs-numeric-logarithms          | Haskell    | 3
# 2731 | memutil                        | Python     | 3
# 2732 | process-tree                   | C++        | 3
# 2733 | closure-net                    | Unknown    | 3
# 2734 | mint-line-follower             | Python     | 3
# 2735 | game-changing-assets           | Jupyter Notebook | 3
# 2736 | docci                          | HTML       | 3
# 2737 | terraform-google-sqlserver     | PowerShell | 3
# 2738 | funke-eudi-wallet-prototype    | Kotlin     | 3
# 2739 | play-core-unity                | C#         | 3
# 2740 | play-in-app-updates-unity      | C#         | 3
# 2741 | ionosphere                     | Jupyter Notebook | 3
# 2742 | loudness_ebur128               | C++        | 3
# 2743 | iwa-vscode-extension           | TypeScript | 3
# 2744 | skcms                          | Unknown    | 3
# 2745 | async-request-dispatcher-rs    | Rust       | 3
# 2746 | YouCompleteSubl                | Unknown    | 2
# 2747 | ts-gulp                        | Unknown    | 2
# 2748 | rtb_troubleshooting_connector  | JavaScript | 2
# 2749 | longt5                         | Unknown    | 2
# 2750 | stable-retraining-conversational-agents | Unknown    | 2
# 2751 | csv2pprof                      | Go         | 2
# 2752 | dsg                            | HTML       | 2
# 2753 | gdb_gcore_point                | Python     | 2
# 2754 | spdm-accelerator-requirement   | Unknown    | 2
# 2755 | osv-scanner-v1                 | Go         | 2
# 2756 | how-unique-is-whose-web-browser | Jupyter Notebook | 2
# 2757 | gcp-scc-iac-validation-utils   | Go         | 2
# 2758 | price_visibility_booster       | JavaScript | 2
# 2759 | webdriver-shadow-dom           | Kotlin     | 2
# 2760 | oxsea                          | Rust       | 2
# 2761 | csv2pprof                      | Go         | 2
# 2762 | osv-scanner-v1                 | Go         | 2
# 2763 | gcp-scc-iac-validation-utils   | Go         | 2
# 2764 | sbom-conformance               | Go         | 2
# 2765 | quahog                         | Go         | 2
# 2766 | oxsea                          | Rust       | 2
# 2767 | lottie-tools                   | Rust       | 2
# 2768 | flyweights                     | Rust       | 2
# 2769 | webdriver-shadow-dom           | Kotlin     | 2
# 2770 | virtual-printer                | Kotlin     | 2
# 2771 | dsg                            | HTML       | 2
# 2772 | how-unique-is-whose-web-browser | Jupyter Notebook | 2
# 2773 | google-cloud-datastore-quadruple | M4         | 2
# 2774 | where-is-my-watch              | Unknown    | 1
# 2775 | usm-voice-transcriber          | Unknown    | 1
# 2776 | cmrt                           | Unknown    | 1
# 2777 | ragvis                         | Unknown    | 1
# 2778 | iba-opt-out-plugin             | JavaScript | 1
# 2779 | dlc-insight-lab                | JavaScript | 1
# 2780 | proto-splitter                 | C++        | 1
# 2781 | p4-infra                       | C++        | 1
# 2782 | rde-tester                     | C++        | 1
# 2783 | ic-modeling-python             | Python     | 1
# 2784 | symphony-gcp                   | Python     | 1
# 2785 | dmabuf_importer_helper         | C          | 1
# 2786 | smc-common                     | C          | 1
# 2787 | smc-hello-world                | C          | 1
# 2788 | appengine-java-migration-samples | Java       | 1
# 2789 | taxinomia                      | Go         | 1
# 2790 | yarsa                          | Go         | 1
# 2791 | receipts-to-riches-part2       | C#         | 1
# 2792 | play-common-unity              | C#         | 1
# 2793 | casimir                        | Rust       | 1
# 2794 | synopsys-dw-uart               | Rust       | 1
# 2795 | bulk-actions-framework         | Apex       | 1
# 2796 | tweakr-codelab                 | Kotlin     | 1
# 2797 | sso-offloading                 | TypeScript | 1
# 2798 | filament-assets                | Mathematica | 1
# 2799 | unblocking-detail-caption      | HTML       | 1
# 2800 | webview-ads                    | HTML       | 1
# 2801 | alu-api                        | Jupyter Notebook | 1
# 2802 | common-multicloud-runtime      | Unknown    | 0
# 2803 | s2a-proto                      | Unknown    | 0
# 2804 | automotive-design-compose-protos | Unknown    | 0
# 2805 | distributed_graph_flow         | Unknown    | 0
# 2806 | graph-renderer                 | Unknown    | 0
# 2807 | refvnli                        | JavaScript | 0
# 2808 | spdmd                          | C++        | 0
# 2809 | gurl                           | C++        | 0
# 2810 | capsem                         | Python     | 0
# 2811 | soql-tool                      | Apex       | 0
# 2812 | codeql-action                  | TypeScript | 0
