# %% [markdown]
# データの永続化：SQLite

# %%
import sqlite3

# %%
# DBファイルの保存先パス
path = ""

#google colabの場合
# path = '/content/'ArithmeticError

#DBファイル
db_name = "test.cb"

# DB接続の確立
# DBファイルが存在しない場合は自動で新規作成
conn = sqlite3.connect(path + db_name)

# DBへの接続を閉じる
conn.close()

# %% [markdown]
# ## こういうデータベースを作成してみる
# | id | name | price |
# | - | - | - |
# |  |  |  |
# |  |  |  |
# |  |  |  |
# ​
# ### DB（SQLite）を使う時の処理の流れ
#
# 1. DBへのコネクションを確立
# 2. コネクションオブジェクトからデータ操作用のカーソルオブジェクトを取得
# 3. 実行したいSQLを定義
# 4. SQLを実行
# 5. 必要があればコミットする
# 6. コネクションを閉じる

# %% [markdown]
# ### テーブルを作成

# %%
path = ""
db_name = "car.db"


try:
    
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL(RDBを操作するための言語)を実行するためのカーソルオブジェクトの取得
    cur = conn.cursor()

    # SQL文の作成
    # テーブルの作成
    spl = "CREATE TABLE cars (id INT, name TEXT, price REAL);"

    # SQL文の実行
    cur.execute(spl)
    
except Exception as e:
    print("エラーが発生しました:", e)

finally:
    # DBへの接続を閉じる    
    conn.close()
# Out:
# エラーが発生しました: table cars already exists

# %% [markdown]
# ### データをDBに挿入する（単一レコード）

# %%
path = ''
db_name = 'car.db'

try:
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL（RDBを操作するための言語）を実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # SQL文の作成
    # データの挿入
    # INSERT INTO テーブル名 VALUES (列に対応したデータをカンマ区切りで);
    # 文字列データを挿入する場合は，文字列をシングルクォーテーションで挟む
    sql = "INSERT INTO cars (id, name, price) VALUES (1, '370z', 7000000);"

    # SQL文の実行
    cur.execute(sql)

    # 変更をDBに反映させる
    conn.commit()

except sqlite3.Error as e:
    print('エラーが発生しました:', e)

finally:
    # DBへの接続を閉じる
    conn.close()

# %% [markdown]
# ### データをDBに挿入する（複数レコード）

# %%
path = ''
db_name = 'car.db'

try:
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL（RDBを操作するための言語）を実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # SQL文の作成
    # 複数レコードの挿入
    # INSERT INTO テーブル名 VALUES (列に対応したプレースホルダーをカンマ区切りで);
    sql = "INSERT INTO cars (id, name, price) VALUES (?, ?, ?);"

    cars = [
        (2, '911カレラ', 15500000),
        (3, 'GRスープラ', 8000000),
        (4, 'シビック Type-R', 5000000)
    ]

    # SQL文の実行
    cur.executemany(sql, cars)
    
    # 変更をDBに反映させる
    conn.commit()

except sqlite3.Error as e:
    print('エラーが発生しました:', e)

finally:
    # DBへの接続を閉じる
    conn.close()

# %% [markdown]
# ### DB内のデータを参照する

# %%
path = ''
db_name = 'car.db'

try:
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL（RDBを操作するための言語）を実行するためのカーソルオブジェクトを取得
    cur = conn.cursor()

    # データを参照するSQL
    # SELECT * FROM テーブル名;
    # * の部分は，取得したい列の名前を，区切りで指定することもできる．
    sql = "SELECT * FROM cars;"

    # SQL文の実行
    cur.execute(sql)

    # 変更をDBに反映させる
    # conn.commit()

except sqlite3.Error as e:
    print('エラーが発生しました:', e)

else:
    for row in cur:
        # 行データ(row)はタプルなので，アンパックして列データを取得
        id, name, price = row
        print(id, name, price)

finally:
    # DBへの接続を閉じる
    conn.close()
# Out:
# 1 370z 7000000.0
# 2 911カレラ 15500000.0
# 3 GRスープラ 8000000.0
# 4 シビック Type-R 5000000.0

# %% [markdown]
# ### データの削除

# %%
path = ""
db_name = "car.db"

try:
    
    
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL(RDBを操作するための言語)を実行するためのカーソルオブジェクトの取得
    cur = conn.cursor()

    # データを削除するSQL
    # DELETE FROM テーブル名 WHERE id = 1;
    spl = "DELETE FROM cars WHERE id = 1;"
    # spl = "DELETE FROM cars WHERE name = 'スープラ';"
    # spl = "DELETE FROM cars WHERE name like = '%カレラ';"
   
    

    # SQL文の実行
    cur.execute(spl)
    
    # 変更をDBに反映させる
    conn.commit()
    
except Exception as e:
    print("エラーが発生しました:", e)
    
finally:
    # DBへの接続を閉じる    
    conn.close()

# %% [markdown]
# ### データの更新

# %%
path = ""
db_name = "car.db"

try:
    
    
    # DB接続オブジェクトの作成
    conn = sqlite3.connect(path + db_name)

    # SQL(RDBを操作するための言語)を実行するためのカーソルオブジェクトの取得
    cur = conn.cursor()

    # データを更新するSQL
    # UPDATE テーブル名 SET カラム名 = 更新値 WHERE 更新したい行を指定する条件;
    spl = "UPDATE cars SET price = ? WHERE id = ?;"
    

    # SQL文の実行
    cur.execute(spl, (50000000, 2))
    
    # 変更をDBに反映させる
    conn.commit()
    
except Exception as e:
    print("エラーが発生しました:", e)
    
finally:
    # DBへの接続を閉じる    
    conn.close()
